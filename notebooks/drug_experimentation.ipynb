# %% [markdown]
# # Exploratory Drug Label Analysis

# %% [markdown]
# Goals of this notebook are to simply take a look at some of the xml files from the [dailymed drug package inserts](https://dailymed.nlm.nih.gov/dailymed/spl-resources-all-drug-labels.cfm).  We'll try to get a handle on how this data looks, how to throw it into a datastructure, and maybe make some plots.  First, let's set up some import and see if we can't read some XML.

# %%
import os
import pprint
import json
import lxml.etree as etree
import pandas as pd
from pandas.io.json import json_normalize
pprint = pprint.pprint #Set up pretty print

# I unpacked some test data here, not all of it is saved to github repo due to size constraints
test_data_dir = '../test_data/dm_spl_daily_update_12142018/prescription/'
drug_dirs = [a for a in os.listdir(test_data_dir) if '.zip' not in a]
# show the names of the dirs and the total number
pprint(drug_dirs[0:5])
len(drug_dirs)
# Out:
# ['20181214_94472ddb-ae1d-4a11-a673-81254d562e6b',
#  '20181214_cea3f6aa-cd1c-4152-98bb-bbb7b977497a',
#  '20181214_6bdbdc53-5e07-159c-e053-2991aa0a5bcc',
#  '20181214_9c6aa884-750e-4b11-9955-bc7ab6e9c2ad',
#  '20181214_93d1d088-1ebb-478e-9715-de067052bff3']
# 246

# %% [markdown]
# Excellent, we have about 250 directories with no useful identifiers built into the dir name.

# %%
print('dir for drug 1:')
print(drug_dirs[0])
pprint(os.listdir(test_data_dir+drug_dirs[0]))
print()

print('dir for drug 2:')
print(drug_dirs[1])
pprint(os.listdir(test_data_dir+drug_dirs[1]))
print()
# Out:
# dir for drug 1:
# 20181214_94472ddb-ae1d-4a11-a673-81254d562e6b
# ['7b291076-36db-9793-e053-2991aa0a9f53.xml',
#  'mar08-0004-01.jpg',
#  'mar08-0004-02.jpg',
#  'mar08-0004-05.jpg',
#  'mar08-0004-04.jpg',
#  'mar08-0004-03.jpg']
#
# dir for drug 2:
# 20181214_cea3f6aa-cd1c-4152-98bb-bbb7b977497a
# ['image-02.jpg',
#  'image-05.jpg',
#  'image-04.jpg',
#  'image-03.jpg',
#  '9e027111-4dce-47fb-bafb-90191891a2f8.xml',
#  'image-06.jpg',
#  'image-01.jpg']

# %% [markdown]
# Looks like each directory has an xml file with a randomized name, not related to the dir name.  It also has some number of images, and those images may or may not include the name of the drug. Lets print an xml file and check it out.

# %%
test_filename = test_data_dir+drug_dirs[0]+'/7b291076-36db-9793-e053-2991aa0a9f53.xml'
x = etree.parse(test_filename)
print(etree.tostring(x, pretty_print=True))
# Out:
# b'<?xml-stylesheet href="http://www.accessdata.fda.gov/spl/stylesheet/spl.xsl" type="text/xsl"?>\n<document xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="urn:hl7-org:v3" xsi:schemaLocation="urn:hl7-org:v3 http://www.accessdata.fda.gov/spl/schema/spl.xsd">\n   <id root="7b291076-36db-9793-e053-2991aa0a9f53"/>\n   <code code="34391-3" codeSystem="2.16.840.1.113883.6.1" displayName="HUMAN PRESCRIPTION DRUG LABEL"/>\n   <title>Dexamethasone Sodium Phosphate Injection,USP</title>\n   <effectiveTime value="20181101"/>\n   <setId root="94472ddb-ae1d-4a11-a673-81254d562e6b"/>\n   <versionNumber value="5"/>\n   <author>\n      <time/>\n      <assignedEntity>\n         <representedOrganization>\n            <id root="1.3.6.1.4.1.519.1" extension="059888437"/>\n            <name>Asclemed USA, Inc.</name>\n            <assignedEntity>\n               <assignedOrganization/>\n            </assignedEntity>\n         </representedOrganization>\n      </assignedEntity>\n   </author>\n   <component>\n      <structuredBody>\n         <component>\n            <section>\n               <id root="7c90ed87-ba66-4a42-e053-2a91aa0a4f38"/>\n               <code code="48780-1" codeSystem="2.16.840.1.113883.6.1" displayName="SPL product data elements section"/>\n               <effectiveTime value="20181101"/>\n               <subject>\n                  <manufacturedProduct>\n                     <manufacturedProduct>\n                        <code code="76420-810" codeSystem="2.16.840.1.113883.6.69"/>\n                        <name>Mardex 25 Kit</name>\n                        <formCode code="C47916" codeSystem="2.16.840.1.113883.3.26.1.1" displayName="KIT"/>\n                        <asEntityWithGeneric>\n                           <genericMedicine>\n                              <name>Dexamethasone Sodium Phosphate, Bupivacaine Hydrochloride, Povidine Iodine</name>\n                           </genericMedicine>\n                        </asEntityWithGeneric>\n                        <asContent>\n                           <quantity>\n                              <numerator value="1" unit="1"/>\n                              <denominator value="1"/>\n                           </quantity>\n                           <containerPackagedProduct>\n                              <code code="76420-810-01" codeSystem="2.16.840.1.113883.6.69"/>\n                              <formCode code="C43182" codeSystem="2.16.840.1.113883.3.26.1.1" displayName="CARTON"/>\n                           </containerPackagedProduct>\n                           <subjectOf>\n                              <characteristic>\n                                 <code code="SPLCMBPRDTP" codeSystem="2.16.840.1.113883.1.11.19255"/>\n                                 <value code="C102834" codeSystem="2.16.840.1.113883.3.26.1.1" displayName="Type 1: Convenience Kit of Co-Package" xsi:type="CV"/>\n                              </characteristic>\n                           </subjectOf>\n                           <subjectOf>\n                              <marketingAct>\n                                 <code code="C53292" codeSystem="2.16.840.1.113883.3.26.1.1"/>\n                                 <statusCode code="active"/>\n                                 <effectiveTime>\n                                    <low value="20140821"/>\n                                 </effectiveTime>\n                              </marketingAct>\n                           </subjectOf>\n                        </asContent>\n                        <part>\n                           <quantity>\n                              <numerator value="1" unit="mL"/>\n                              <denominator value="1"/>\n                           </quantity>\n                           <partProduct>\n                              <code code="63323-506" codeSystem="2.16.840.1.113883.6.69"/>\n                              <name>Dexamethasone Sodium Phosphate</name>\n                              <formCod ...

# %% [markdown]
# That's too much to deal with.  Let's read it into pandas.

# %%
df_list = pd.read_html(test_filename, flavor='bs4') # This will convert an xml file into a list of DataFrames
print(len(df_list))
# Out:
# 7

# %%
for i,df in enumerate(df_list):
    print(f'Dataframe: {i}')
    display(df)
# Out:
# Dataframe: 0
#              0                                                  1
# 0       Author                                             Dosage
# 1  Cavanagh  1  3 mg/kg of body weight per 24 hours by constan...
# 2          NaN                                                NaN
# 3  Dietzman  2  2 to 6 mg/kg of body weight as a single intrav...
# 4          NaN                                                NaN
# 5     Frank  3  40 mg initially followed by repeat intravenous...
# 6          NaN                                                NaN
# 7      Oaks  4  40 mg initially followed by repeat intravenous...
# 8          NaN                                                NaN
# 9   Schumer  5  1 mg/kg of body weight as a single intravenous...
# Dataframe: 1
#              0             1         2          3
# 0  Product No.      NDC  No.  Strength  Vial Size
# 1       500601  63323-506-01  10 mg/mL       1 mL
# Dataframe: 2
#              0             1         2          3
# 0  Product No.      NDC  No.  Strength  Vial Size
# 1       501610  63323-516-10  10 mg/mL      10 mL
# Dataframe: 3
#                                                    0
# 0  THE 0.75% CONCENTRATION OF BUPIVACAINE HYDROCH...
# Dataframe: 4
#                                                     0            1  \
# 0                                      Type of  Block        Conc.
# 1                                                (mL)         (mg)
# 2                                 Local  infiltration      0.25% 4
# 3                                            Epidural    0.75% 2,4
# 4                                              0.5% 4        10-20
# 5                                             0.25% 4        10-20
# 6                                              Caudal       0.5% 4
# 7                                             0.25% 4        15-30
# 8                                   Peripheral nerves       0.5% 4
# 9                                             0.25% 4    5 to max.
# 10                                      Retrobulbar 3      0.75% 4
# 11                                        Sympathetic        0.25%
# 12                                           Dental 3  0.5%  w/epi
# 13                              Epidural 3  Test Dose  0.5%  w/epi
# 14  1With continuous (intermittent) techniques, re...          NaN
#
#                    2                                     3  \
# 0          Each Dose                         Motor Block 1
# 1                NaN                                   NaN
# 2        up to  max.                            up to max.
# 3              10-20                                75-150
# 4             50-100                  moderate to complete
# 5              25-50                  partial  to moderate
# 6              15-30                                75-150
# 7            37.5-75                              moderate
# 8         5 to  max.                            25 to max.
# 9      12.5 to  max.                 moderate  to complete
# 10               2-4                                 15-30
# 11             20-50                                50-125
# 12  1.8-3.6 per site                         9-18 per site
# 13               2-3  10-15 (10-15 micrograms epinephrine)
# 14               NaN                                   NaN
#
#                         4
# 0                     NaN
# 1                     NaN
# 2                       —
# 3                complete
# 4                     NaN
# 5                     NaN
# 6    moderate to complete
# 7                     NaN
# 8   moderate  to complete
# 9                     NaN
# 10               complete
# 11                      —
# 12                      —
# 13                      —
# 14                    NaN
# Dataframe: 5
#                0                                                  1      2  \
# 0        NDC No.                                          Container   Fill
# 1            NaN  0.25%—Contains 2.5 mg bupivacaine hydrochlorid...    NaN
# 2   0409-1559-10                                  Single-dose vials  10 mL
# 3   0409-1559-30                                  Single-dose vials  30 mL
# 4   0409-1587-50                                Multiple-dose vials  50 mL
# 5            NaN  0.5%—Contains 5 mg bupivacaine hydrochloride p...    NaN
# 6   0409-1560-10                                  Single-dose vials  10 mL
# 7   0409-1560-29                                  Single-dose vials  30 mL
# 8   0409-1610-50                                Multiple-dose vials  50 mL
# 9            NaN  0.75%—Contains 7.5 mg bupivacaine hydrochlorid...    NaN
# 10  0409-1582-10                                  Single-dose vials  10 mL
# 11  0409-1582-29                                  Single-dose vials  30 mL
#
#             3
# 0    Quantity
# 1         NaN
# 2   box of 10
# 3   box of 10
# 4    box of 1
# 5         NaN
# 6   box of 10
# 7   box of 10
# 8    box of 1
# 9         NaN
# 10  box of 10
# 11  box of 10
# Dataframe: 6
#                                                    0                    1  \
# 0                                            NDC No.            Container
# 1  0.25% with epinephrine 1:200,000—Contains 2.5 ...                  NaN
# 2                                       0409-1746-10    Single-dose vials
# 3                                       0409-1746-30    Single-dose vials
# 4                                       0409-1752-50  Multiple-dose vials
# 5  0.5% with epinephrine 1:200,000—Contains 5 mg ...                  NaN
# 6                                       0409-1749-03   Single-dose ampuls
# 7                                       0409-1749-10    Single-dose vials
# 8                                       0409-1749-29    Single-dose vials
# 9                                       0409-1755-50  Multiple-dose vials
#
#        2          3
# 0   Fill   Quantity
# 1    NaN        NaN
# 2  10 mL  box of 10
# 3  30 mL  box of 10
# 4  50 mL   box of 1
# 5    NaN        NaN
# 6   3 mL  box of 10
# 7  10 mL  box of 10
# 8  30 mL  box of 10
# 9  50 mL   box of 1

# %% [raw]
# This also looks awful.  Pandas has not scraped the majority of content.  Instead, it only seems to have grabbed items that are formatted in a tabular manner, which misses very important information (the drug name, for instance...).  This is a very messy xml file that will be difficult to parse, and will probably require a parsing engine made by hand.  Before we do that... maybe someone has tried to do this already?  A bit of googling leads to a different resource:

# %% [markdown]
# # OpenFDA database

# %% [markdown]
# Looks like the [openFDA](https://open.fda.gov/tools/downloads/) has currated json files from the FDA label xml files.  This probably doesn't have everything we need, but it is almost certainly a cleaner way to start.

# %%
data = json.load(open('../test_data/drug-label-0001-of-0007.json'))
print(data.keys())
data['meta']
# Out:
# dict_keys(['meta', 'results'])
# {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#  'last_updated': '2018-12-14',
#  'license': 'https://open.fda.gov/license/',
#  'results': {'limit': 20000, 'skip': 0, 'total': 131198},
#  'terms': 'https://open.fda.gov/terms/'}

# %% [markdown]
# Well we have two keys, 'meta' and 'results'.  If we take a quick peak, we know that we don't really care about meta.  I bet 'results' is more promising...

# %%
df = pd.DataFrame(data['results'])
df
# Out:
#       abuse accessories                                  active_ingredient  \
# 0       NaN         NaN  [HPUS Active Ingredients Each dose contains eq...
# 1       NaN         NaN          [Active ingredient Colloidal oatmeal 43%]
# 2       NaN         NaN                                                NaN
# 3       NaN         NaN  [Active ingredient (in each extended-release t...
# 4       NaN         NaN                                                NaN
# 5       NaN         NaN  [ACTIVE INGREDIENT Active Ingredient: Hamameli...
# 6       NaN         NaN          [Active ingredient Benzoyl Peroxide 2.5%]
# 7       NaN         NaN  [ACTIVE INGREDIENTS: Arsenicum Album 12X, Calc...
# 8       NaN         NaN  [DRUG FACTS Active Ingredient Miconazole Nitra...
# 9       NaN         NaN                                                NaN
# 10      NaN         NaN  [Active ingredients (in each 30 mL dose cup) P...
# 11      NaN         NaN                                                NaN
# 12      NaN         NaN               [Active ingredient Mineral oil 100%]
# 13      NaN         NaN  [ACTIVE INGREDIENT Active Ingredients: SOPHORA...
# 14      NaN         NaN  [Carton Active Ingredients Section Active ingr...
# 15      NaN         NaN              [Active Ingredient Ethyl Alcohol 62%]
# 16      NaN         NaN                 [Active ingredient Triclosan 0.3%]
# 17      NaN         NaN  [ACTIVE INGREDIENTS: Clematis Vitalba, Flos 30...
# 18      NaN         NaN              [Active Ingredient Ethyl Alcohol 62%]
# 19      NaN         NaN  [Active Ingredient: OCTINOXATE: 7.5% OCTISALAT...
# 20      NaN         NaN  [ACTIVE INGREDIENTS: Arsenicum Album 30C, Lyco...
# 21      NaN         NaN  [Active ingredient (in each softgel) Dextromet...
# 22      NaN         NaN  [ACTIVE INGREDIENTS: Symphytum Officinale 6X, ...
# 23      NaN         NaN                                                NaN
# 24      NaN         NaN                                                NaN
# 25      NaN         NaN                                                NaN
# 26      NaN         NaN  [Benzethonium Chloride 0.2% w/w.....Antibacter...
# 27      NaN         NaN            [ACTIVE INGREDIENTS Red ginseng 17.19%]
# 28      NaN         NaN                                                NaN
# 29      NaN         NaN  [Carton Active Ingredients Section Active ingr...
# ...     ...         ...                                                ...
# 19970   NaN         NaN                                                NaN
# 19971   NaN         NaN                                                NaN
# 19972   NaN         NaN                                                NaN
# 19973   NaN         NaN                                                NaN
# 19974   NaN         NaN                                                NaN
# 19975   NaN         NaN                 [ACTIVE INGREDIENTS EUPHORBIA PIL]
# 19976   NaN         NaN                  [ACTIVE INGREDIENTS LONICERA PER]
# 19977   NaN         NaN                     [ACTIVE INGREDIENTS GELSEMIUM]
# 19978   NaN         NaN                                                NaN
# 19979   NaN         NaN                [Saccharum officinale 6X,30C,200CK]
# 19980   NaN         NaN  [Active Ingredients Camphor 4.8% Eucalyptus oi...
# 19981   NaN         NaN                                                NaN
# 19982   NaN         NaN                                                NaN
# 19983   NaN         NaN                                                NaN
# 19984   NaN         NaN  [Active ingredient Purpose Sodium flyoride 0.0...
# 19985   NaN         NaN                                                NaN
# 19986   NaN         NaN                                                NaN
# 19987   NaN         NaN                                                NaN
# 19988   NaN         NaN                                                NaN
# 19989   NaN         NaN  [Active ingredients Active ingredients Avobenz...
# 19990   NaN         NaN                                                NaN
# 19991   NaN         NaN                                                NaN
# 19992   NaN         NaN                                                NaN
# 19993   NaN         NaN                                                NaN
# 19994   NaN         NaN                                                NaN
# 19995   NaN         NaN                                                NaN
# 19996   NaN         NaN  [Ethyl Alcohol 62.0%.............................
# 19997   NaN         NaN                     [Active ingredient Tolnaftate]
# 19998   NaN         NaN                                                NaN
# 19999   NaN         NaN  [Active Ingredients Purpose Octinoxate 5% Suns...
#
#                                  active_ingredient_table  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 19970                                                NaN
# 19971                                                NaN
# 19972                                                NaN
# 19973                                                NaN
# 19974                                                NaN
# 19975                                                NaN
# 19976                                                NaN
# 19977                                                NaN
# 19978                                                NaN
# 19979                                                NaN
# 19980                                                NaN
# 19981                                                NaN
# 19982                                                NaN
# 19983                                                NaN
# 19984                                                NaN
# 19985                                                NaN
# 19986                                                NaN
# 19987                                                NaN
# 19988                                                NaN
# 19989                                                NaN
# 19990                                                NaN
# 19991                                                NaN
# 19992                                                NaN
# 19993                                                NaN
# 19994                                                NaN
# 19995                                                NaN
# 19996                                                NaN
# 19997                                                NaN
# 19998                                                NaN
# 19999  [<table width="70%"> <col width="50%" align="l...
#
#                                        adverse_reactions  \
# 0                                                    NaN
# 1                                                    NaN
# 2      [6 ADVERSE REACTIONS Use of levocetirizine dih...
# 3                                                    NaN
# 4      [6 ADVERSE REACTIONS The most common adverse r...
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9      [6 ADVERSE REACTIONS Reactions to articaine ar...
# 10                                                   NaN
# 11     [ADVERSE REACTIONS Observed in Controlled Clin...
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23     [ADVERSE REACTIONS Gastrointestinal Onset of p...
# 24     [6 ADVERSE REACTIONS The following serious adv...
# 25     [ADVERSE REACTIONS Following the administratio...
# 26                                                   NaN
# 27                                                   NaN
# 28     [ADVERSE REACTIONS Psychiatric disorders: Nerv...
# 29                                                   NaN
# ...                                                  ...
# 19970  [6 ADVERSE REACTIONS In controlled, clinical t...
# 19971  [ADVERSE REACTIONS Associated with Discontinua...
# 19972  [6 ADVERSE REACTIONS The following serious adv...
# 19973  [ADVERSE REACTIONS Adverse reactions to tamoxi...
# 19974  [ADVERSE REACTIONS Serious adverse reactions h...
# 19975                                                NaN
# 19976                                                NaN
# 19977                                                NaN
# 19978  [ADVERSE REACTIONS Due to oral doxycycline’s v...
# 19979                                                NaN
# 19980                                                NaN
# 19981  [ADVERSE REACTIONS Drowsiness, dry mouth, and ...
# 19982                                                NaN
# 19983  [ADVERSE REACTIONS The following have been rep...
# 19984                                                NaN
# 19985  [ADVERSE REACTIONS The following adverse event...
# 19986  [ADVERSE REACTIONS Most adverse effects are mi...
# 19987  [ADVERSE REACTIONS: Developing teeth of childr...
# 19988  [ADVERSE REACTIONS Lisinopril has been found t...
# 19989                                                NaN
# 19990  [ADVERSE REACTIONS (See also WARNINGS and PREC...
# 19991                                                NaN
# 19992                                                NaN
# 19993  [ADVERSE REACTIONS In multiple dose, placebo-c...
# 19994  [6 ADVERSE REACTIONS Use of VENTOLIN HFA may b...
# 19995  [ADVERSE REACTIONS Respiratory Depression Prom...
# 19996                                                NaN
# 19997                                                NaN
# 19998                                                NaN
# 19999                                                NaN
#
#                                  adverse_reactions_table  \
# 0                                                    NaN
# 1                                                    NaN
# 2      [<table ID="_RefID0EWPAC" width="75%"> <captio...
# 3                                                    NaN
# 4      [<table ID="_RefID0EOOAG" width="100%"> <capti...
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9      [<table ID="table2" width="75%"> <caption>Tabl...
# 10                                                   NaN
# 11     [<table cellspacing="0" cellpadding="0" border...
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24     [<table ID="_RefID2BE7A7F368754EE78A256651660B...
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 19970                                                NaN
# 19971  [<table border="0" cellpadding="0" cellspacing...
# 19972  [<table cellspacing="0" cellpadding="0" border...
# 19973  [<table> <col/> <col/> <col/> <tfoot> <tr> <td...
# 19974  [<table width="85%"> <col width="29%"/> <col w...
# 19975                                                NaN
# 19976                                                NaN
# 19977                                                NaN
# 19978                                                NaN
# 19979                                                NaN
# 19980                                                NaN
# 19981                                                NaN
# 19982                                                NaN
# 19983                                                NaN
# 19984                                                NaN
# 19985                                                NaN
# 19986                                                NaN
# 19987                                                NaN
# 19988  [<table border="1" width="435.000" ID="inv-751...
# 19989                                                NaN
# 19990  [<table width="0.000" ID="id_d436d006-8eb7-466...
# 19991                                                NaN
# 19992                                                NaN
# 19993  [<table ID="table1"> <thead> <tr> <th align="c...
# 19994  [<table border="single" width="463.000" ID="id...
# 19995                                                NaN
# 19996                                                NaN
# 19997                                                NaN
# 19998                                                NaN
# 19999                                                NaN
#
#                    animal_pharmacology_and_or_toxicology  \
# 0                                                    NaN
# 1                                                    NaN
# 2      [13.2 Animal Toxicology Reproductive Toxicolog...
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24          [13.2 Animal Toxicology and/or Pharmacology]
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 19970                                                NaN
# 19971                                                NaN
# 19972                                                NaN
# 19973                                                NaN
# 19974                                                NaN
# 19975                                                NaN
# 19976                                                NaN
# 19977                                                NaN
# 19978  [ANIMAL PHARMACOLOGY AND ANIMAL TOXICOLOGY Hyp...
# 19979                                                NaN
# 19980                                                NaN
# 19981                                                NaN
# 19982                                                NaN
# 19983                                                NaN
# 19984                                                NaN
# 19985                                                NaN
# 19986                                                NaN
# 19987                                                NaN
# 19988                                                NaN
# 19989                                                NaN
# 19990                                                NaN
# 19991                                                NaN
# 19992                                                NaN
# 19993                                                NaN
# 19994  [13.2 Animal Toxicology and/or Pharmacology Pr...
# 19995                                                NaN
# 19996                                                NaN
# 19997                                                NaN
# 19998                                                NaN
# 19999                                                NaN
#
#                                               ask_doctor  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      [Ask a doctor before use if you have •persiste...
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10     [Ask a doctor before use if you have liver dis...
# 11                                                   NaN
# 12     [Ask a doctor before use if you have stomach r...
# 13                                                   NaN
# 14     [Ask a doctor Stop use and ask a doctor if ras...
# 15     [Do not inhale or ingest. Stop use and ask a d...
# 16                                                   NaN
# 17                                                   NaN
# 18     [Do not inhale or ingest. Stop use and ask a d...
# 19           [Stop Use and Ask a Doctor if: Rash occurs]
# 20                                                   NaN
# 21     [Ask a doctor before use if the user has a cou...
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29     [Ask a doctor Stop use and ask a doctor if ras...
# ...                                                  ...
# 19970                                                NaN
# 19971                                                NaN
# 19972                                                NaN
# 19973                                                NaN
# 19974                                                NaN
# 19975                                                NaN
# 19976                                                NaN
# 19977                                                NaN
# 19978                                                NaN
# 19979                                                NaN
# 19980  [Ask a doctor before use if you have Asthma Ex...
# 19981                                                NaN
# 19982                                                NaN
# 19983                                                NaN
# 19984                                                NaN
# 19985                                                NaN
# 19986                                                NaN
# 19987                                                NaN
# 19988                                                NaN
# 19989                                                NaN
# 19990                                                NaN
# 19991                                                NaN
# 19992                                                NaN
# 19993                                                NaN
# 19994                                                NaN
# 19995                                                NaN
# 19996                                                NaN
# 19997                                                NaN
# 19998                                                NaN
# 19999                                                NaN
#
#       ask_doctor_or_pharmacist ask_doctor_or_pharmacist_table  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
# 5                          NaN                            NaN
# 6                          NaN                            NaN
# 7                          NaN                            NaN
# 8                          NaN                            NaN
# 9                          NaN                            NaN
# 10                         NaN                            NaN
# 11                         NaN                            NaN
# 12                         NaN                            NaN
# 13                         NaN                            NaN
# 14                         NaN                            NaN
# 15                         NaN                            NaN
# 16                         NaN                            NaN
# 17                         NaN                            NaN
# 18                         NaN                            NaN
# 19                         NaN                            NaN
# 20                         NaN                            NaN
# 21                         NaN                            NaN
# 22                         NaN                            NaN
# 23                         NaN                            NaN
# 24                         NaN                            NaN
# 25                         NaN                            NaN
# 26                         NaN                            NaN
# 27                         NaN                            NaN
# 28                         NaN                            NaN
# 29                         NaN                            NaN
# ...                        ...                            ...
# 19970                      NaN                            NaN
# 19971                      NaN                            NaN
# 19972                      NaN                            NaN
# 19973                      NaN                            NaN
# 19974                      NaN                            NaN
# 19975                      NaN                            NaN
# 19976                      NaN                            NaN
# 19977                      NaN                            NaN
# 19978                      NaN                            NaN
# 19979                      NaN                            NaN
# 19980                      NaN                            NaN
# 19981                      NaN                            NaN
# 19982                      NaN                            NaN
# 19983                      NaN                            NaN
# 19984                      NaN                            NaN
# 19985                      NaN                            NaN
# 19986                      NaN                            NaN
# 19987                      NaN                            NaN
# 19988                      NaN                            NaN
# 19989                      NaN                            NaN
# 19990                      NaN                            NaN
# 19991                      NaN                            NaN
# 19992                      NaN                            NaN
# 19993                      NaN                            NaN
# 19994                      NaN                            NaN
# 19995                      NaN                            NaN
# 19996                      NaN                            NaN
# 19997                      NaN                            NaN
# 19998                      NaN                            NaN
# 19999                      NaN                            NaN
#
#             ...                         use_in_specific_populations_table  \
# 0           ...                                                       NaN
# 1           ...                                                       NaN
# 2           ...                                                       NaN
# 3           ...                                                       NaN
# 4           ...                                                       NaN
# 5           ...                                                       NaN
# 6           ...                                                       NaN
# 7           ...                                                       NaN
# 8           ...                                                       NaN
# 9           ...                                                       NaN
# 10          ...                                                       NaN
# 11          ...                                                       NaN
# 12          ...                                                       NaN
# 13          ...                                                       NaN
# 14          ...                                                       NaN
# 15          ...                                                       NaN
# 16          ...                                                       NaN
# 17          ...                                                       NaN
# 18          ...                                                       NaN
# 19          ...                                                       NaN
# 20          ...                                                       NaN
# 21          ...                                                       NaN
# 22          ...                                                       NaN
# 23          ...                                                       NaN
# 24          ...                                                       NaN
# 25          ...                                                       NaN
# 26          ...                                                       NaN
# 27          ...                                                       NaN
# 28          ...                                                       NaN
# 29          ...                                                       NaN
# ...         ...                                                       ...
# 19970       ...                                                       NaN
# 19971       ...                                                       NaN
# 19972       ...                                                       NaN
# 19973       ...                                                       NaN
# 19974       ...                                                       NaN
# 19975       ...                                                       NaN
# 19976       ...                                                       NaN
# 19977       ...                                                       NaN
# 19978       ...                                                       NaN
# 19979       ...                                                       NaN
# 19980       ...                                                       NaN
# 19981       ...                                                       NaN
# 19982       ...                                                       NaN
# 19983       ...                                                       NaN
# 19984       ...                                                       NaN
# 19985       ...                                                       NaN
# 19986       ...                                                       NaN
# 19987       ...                                                       NaN
# 19988       ...                                                       NaN
# 19989       ...                                                       NaN
# 19990       ...                                                       NaN
# 19991       ...                                                       NaN
# 19992       ...                                                       NaN
# 19993       ...                                                       NaN
# 19994       ...         [<table border="single" width="474.000" ID="id...
# 19995       ...                                                       NaN
# 19996       ...                                                       NaN
# 19997       ...                                                       NaN
# 19998       ...                                                       NaN
# 19999       ...                                                       NaN
#
#       user_safety_warnings version veterinary_indications  \
# 0                      NaN       1                    NaN
# 1                      NaN       1                    NaN
# 2                      NaN       1                    NaN
# 3                      NaN       1                    NaN
# 4                      NaN       1                    NaN
# 5                      NaN       1                    NaN
# 6                      NaN       1                    NaN
# 7                      NaN       1                    NaN
# 8                      NaN       1                    NaN
# 9                      NaN       1                    NaN
# 10                     NaN       1                    NaN
# 11                     NaN       1                    NaN
# 12                     NaN       1                    NaN
# 13                     NaN       1                    NaN
# 14                     NaN       2                    NaN
# 15                     NaN       1                    NaN
# 16                     NaN       1                    NaN
# 17                     NaN       1                    NaN
# 18                     NaN       1                    NaN
# 19                     NaN       1                    NaN
# 20                     NaN       1                    NaN
# 21                     NaN       1                    NaN
# 22                     NaN       1                    NaN
# 23                     NaN       1                    NaN
# 24                     NaN       1                    NaN
# 25                     NaN       1                    NaN
# 26                     NaN       2                    NaN
# 27                     NaN       1                    NaN
# 28                     NaN       1                    NaN
# 29                     NaN       1                    NaN
# ...                    ...     ...                    ...
# 19970                  NaN       2                    NaN
# 19971                  NaN       1                    NaN
# 19972                  NaN       4                    NaN
# 19973                  NaN       1                    NaN
# 19974                  NaN       1                    NaN
# 19975                  NaN       1                    NaN
# 19976                  NaN       1                    NaN
# 19977                  NaN       1                    NaN
# 19978                  NaN       1                    NaN
# 19979                  NaN       1                    NaN
# 19980                  NaN       1                    NaN
# 19981                  NaN       1                    NaN
# 19982                  NaN       1                    NaN
# 19983                  NaN       1                    NaN
# 19984                  NaN       1                    NaN
# 19985                  NaN       1                    NaN
# 19986                  NaN       1                    NaN
# 19987                  NaN     104                    NaN
# 19988                  NaN       1                    NaN
# 19989                  NaN       3                    NaN
# 19990                  NaN       1                    NaN
# 19991                  NaN       1                    NaN
# 19992                  NaN       1                    NaN
# 19993                  NaN       1                    NaN
# 19994                  NaN       1                    NaN
# 19995                  NaN       1                    NaN
# 19996                  NaN     251                    NaN
# 19997                  NaN       1                    NaN
# 19998                  NaN       1                    NaN
# 19999                  NaN       1                    NaN
#
#                                                 warnings  \
# 0      [Warnings If symptoms persist or worsen, consu...
# 1      [Warnings For external use only. When using th...
# 2                                                    NaN
# 3      [Warnings Do not use •for children under 12 ye...
# 4                                                    NaN
# 5      [WARNINGS Warnings: 1. If the following sympto...
# 6                       [Warnings For external use only]
# 7      [WARNINGS: If pregnant or breastfeeding, ask a...
# 8      [WARNINGS For external use only Do not use : O...
# 9                                                    NaN
# 10     [Warnings Liver warning: This product contains...
# 11     [WARNINGS ATRACURIUM SHOULD BE USED ONLY BY TH...
# 12     [Warnings Do not use if you have difficulty sw...
# 13     [WARNINGS Warnings: 1. Stop using the product ...
# 14                                                   NaN
# 15     [For external use only-hands Flammable. Keep a...
# 16     [Warnings For external use only. Do not use th...
# 17     [WARNINGS: If pregnant or breast-feeding, ask ...
# 18     [For external use only-hands Flammable. Keep a...
# 19     [Warning: For external use only Do not use on ...
# 20     [WARNINGS: Keep out of reach of children. In c...
# 21     [Warnings Do not use if you are now taking a p...
# 22     [WARNINGS: If pregnant or nursing, consult a h...
# 23     [WARNINGS BEFORE THERAPY WITH CEPHALEXIN IS IN...
# 24                                                   NaN
# 25     [WARNINGS General Hydroxychloroquine sulfate i...
# 26     [For external use only. Avoid contact with eye...
# 27     [WARNING If you take any serious medications o...
# 28     [WARNINGS, General PLAQUENIL is not effective ...
# 29                                                   NaN
# ...                                                  ...
# 19970                                                NaN
# 19971  [WARNINGS Clinical Worsening and Suicide Risk ...
# 19972                                                NaN
# 19973  [WARNINGS Effects in Metastatic Breast Cancer ...
# 19974  [WARNINGS Cardiac Conduction: Diltiazem prolon...
# 19975  [STOP USE AND ASK DOCTOR If symptoms persist/w...
# 19976  [STOP USE AND ASK DOCTOR If symptoms persist/w...
# 19977  [STOP USE AND ASK DOCTOR If symptoms persist/w...
# 19978  [WARNINGS The use of drugs of the tetracycline...
# 19979                                                 []
# 19980  [Warning For external use only. Avoid contact ...
# 19981  [WARNINGS Since drowsiness may, on occasion, o...
# 19982                                                NaN
# 19983                                                NaN
# 19984  [Warning Keep out of reach of children. If mor...
# 19985  [WARNINGS Angina Pectoris There have been repo...
# 19986  [WARNINGS Withdrawal: Patients should be instr...
# 19987                                                NaN
# 19988  [WARNINGS Anaphylactoid and Possibly Related R...
# 19989  [Warnings Warnings For external use only When ...
# 19990  [WARNINGS Clinical Worsening and Suicide Risk ...
# 19991                                                NaN
# 19992                                                NaN
# 19993  [WARNINGS Limited Data Base for Chronic Use of...
# 19994                                                NaN
# 19995  [WARNINGS Respiratory Depression Pediatrics Pr...
# 19996  [For external Use only. Flammable. Keep away f...
# 19997                   [Warnings For external use only]
# 19998  [Warnings For external use only-Not for intern...
# 19999  [Warnings For external use only. When using th...
#
#                                    warnings_and_cautions  \
# 0                                                    NaN
# 1                                                    NaN
# 2      [5 WARNINGS AND PRECAUTIONS 1.Avoid engaging i...
# 3                                                    NaN
# 4      [5 WARNINGS AND PRECAUTIONS •Angioedema: incre...
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9      [5 WARNINGS AND PRECAUTIONS Accidental Intrava...
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14     [Warnings For external use only Do not use on ...
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24     [5 WARNINGS AND PRECAUTIONS Skeletal muscle ef...
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29     [Warnings For external use only Do not use on ...
# ...                                                  ...
# 19970  [5 WARNINGS AND PRECAUTIONS Clobetasol propion...
# 19971                                                NaN
# 19972  [5 WARNINGS AND PRECAUTIONS Increased mortalit...
# 19973                                                NaN
# 19974                                                NaN
# 19975                                                NaN
# 19976                                                NaN
# 19977                                                NaN
# 19978                                                NaN
# 19979                                                NaN
# 19980                                                NaN
# 19981                                                NaN
# 19982                                                NaN
# 19983                                                NaN
# 19984                                                NaN
# 19985                                                NaN
# 19986                                                NaN
# 19987  [WARNINGS: DO NOT SWALLOW Accidental ingestion...
# 19988                                                NaN
# 19989                                                NaN
# 19990                                                NaN
# 19991                                                NaN
# 19992                                                NaN
# 19993                                                NaN
# 19994  [5 WARNINGS AND PRECAUTIONS Paradoxical bronch...
# 19995                                                NaN
# 19996                                                NaN
# 19997                                                NaN
# 19998                                                NaN
# 19999                                                NaN
#
#                              warnings_and_cautions_table  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24     [<table ID="_RefID088259FE67504F2D867F130C820E...
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 19970                                                NaN
# 19971                                                NaN
# 19972                                                NaN
# 19973                                                NaN
# 19974                                                NaN
# 19975                                                NaN
# 19976                                                NaN
# 19977                                                NaN
# 19978                                                NaN
# 19979                                                NaN
# 19980                                                NaN
# 19981                                                NaN
# 19982                                                NaN
# 19983                                                NaN
# 19984                                                NaN
# 19985                                                NaN
# 19986                                                NaN
# 19987                                                NaN
# 19988                                                NaN
# 19989                                                NaN
# 19990                                                NaN
# 19991                                                NaN
# 19992                                                NaN
# 19993                                                NaN
# 19994                                                NaN
# 19995                                                NaN
# 19996                                                NaN
# 19997                                                NaN
# 19998                                                NaN
# 19999                                                NaN
#
#                                           warnings_table  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 19970                                                NaN
# 19971  [<table border="0" cellpadding="0" cellspacing...
# 19972                                                NaN
# 19973                                                NaN
# 19974                                                NaN
# 19975                                                NaN
# 19976                                                NaN
# 19977                                                NaN
# 19978                                                NaN
# 19979                                                NaN
# 19980                                                NaN
# 19981                                                NaN
# 19982                                                NaN
# 19983                                                NaN
# 19984                                                NaN
# 19985                                                NaN
# 19986                                                NaN
# 19987                                                NaN
# 19988                                                NaN
# 19989                                                NaN
# 19990  [<table width="730.000" ID="id_403e42f1-7afe-4...
# 19991                                                NaN
# 19992                                                NaN
# 19993                                                NaN
# 19994                                                NaN
# 19995                                                NaN
# 19996                                                NaN
# 19997                                                NaN
# 19998                                                NaN
# 19999                                                NaN
#
#                                               when_using when_using_table
# 0                                                    NaN              NaN
# 1      [When using this product Do not get into eyes....              NaN
# 2                                                    NaN              NaN
# 3                                                    NaN              NaN
# 4                                                    NaN              NaN
# 5                                                    NaN              NaN
# 6      [When Using This Product • avoid unnecessary s...              NaN
# 7                                                    NaN              NaN
# 8      [When using this product avoid contact with th...              NaN
# 9                                                    NaN              NaN
# 10     [When using this product excitability may occu...              NaN
# 11                                                   NaN              NaN
# 12     [When using this product do not take with meal...              NaN
# 13                                                   NaN              NaN
# 14                                                   NaN              NaN
# 15                                                   NaN              NaN
# 16     [When using this product •avoid contact with e...              NaN
# 17                                                   NaN              NaN
# 18                                                   NaN              NaN
# 19     [When using this product: Keep out of eyes. Ri...              NaN
# 20                                                   NaN              NaN
# 21                                                   NaN              NaN
# 22                                                   NaN              NaN
# 23                                                   NaN              NaN
# 24                                                   NaN              NaN
# 25                                                   NaN              NaN
# 26                                                   NaN              NaN
# 27     [USES to help the treatment and prevention of ...              NaN
# 28                                                   NaN              NaN
# 29                                                   NaN              NaN
# ...                                                  ...              ...
# 19970                                                NaN              NaN
# 19971                                                NaN              NaN
# 19972                                                NaN              NaN
# 19973                                                NaN              NaN
# 19974                                                NaN              NaN
# 19975                                                NaN              NaN
# 19976                                                NaN              NaN
# 19977                                                NaN              NaN
# 19978                                                NaN              NaN
# 19979                                                NaN              NaN
# 19980                                                NaN              NaN
# 19981                                                NaN              NaN
# 19982                                                NaN              NaN
# 19983                                                NaN              NaN
# 19984                                                NaN              NaN
# 19985                                                NaN              NaN
# 19986                                                NaN              NaN
# 19987                                                NaN              NaN
# 19988                                                NaN              NaN
# 19989                                                NaN              NaN
# 19990                                                NaN              NaN
# 19991                                                NaN              NaN
# 19992                                                NaN              NaN
# 19993                                                NaN              NaN
# 19994                                                NaN              NaN
# 19995                                                NaN              NaN
# 19996  [When using this product avoid contact with fa...              NaN
# 19997  [When using this product do not get into eyes....              NaN
# 19998                                                NaN              NaN
# 19999  [When using this product Keep out of eyes. Rin...              NaN
#
# [20000 rows x 133 columns]

# %% [markdown]
# We have tabular data now, at least.  More investigation to continue...
