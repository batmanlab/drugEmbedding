# %% [markdown]
# # Exploratory Drug Label Analysis

# %% [markdown]
# Goals of this notebook are to simply take a look at some of the xml files from the [dailymed drug package inserts](https://dailymed.nlm.nih.gov/dailymed/spl-resources-all-drug-labels.cfm).  We'll try to get a handle on how this data looks, how to throw it into a datastructure, and maybe make some plots.  First, let's set up some import and see if we can't read some XML.

# %%
import os
import pprint
import json
import lxml.etree as etree
import pandas as pd
from pandas.io.json import json_normalize
pprint = pprint.pprint #Set up pretty print

# I unpacked some test data here, not all of it is saved to github repo due to size constraints
test_data_dir = '../test_data/dm_spl_daily_update_12142018/prescription/'
drug_dirs = [a for a in os.listdir(test_data_dir) if '.zip' not in a]
# show the names of the dirs and the total number
pprint(drug_dirs[0:5])
len(drug_dirs)
# Out:
# ['20181214_94472ddb-ae1d-4a11-a673-81254d562e6b',
#  '20181214_cea3f6aa-cd1c-4152-98bb-bbb7b977497a',
#  '20181214_6bdbdc53-5e07-159c-e053-2991aa0a5bcc',
#  '20181214_9c6aa884-750e-4b11-9955-bc7ab6e9c2ad',
#  '20181214_93d1d088-1ebb-478e-9715-de067052bff3']
# 246

# %% [markdown]
# Excellent, we have about 250 directories with no useful identifiers built into the dir name.

# %%
print('dir for drug 1:')
print(drug_dirs[0])
pprint(os.listdir(test_data_dir+drug_dirs[0]))
print()

print('dir for drug 2:')
print(drug_dirs[1])
pprint(os.listdir(test_data_dir+drug_dirs[1]))
print()
# Out:
# dir for drug 1:
# 20181214_94472ddb-ae1d-4a11-a673-81254d562e6b
# ['7b291076-36db-9793-e053-2991aa0a9f53.xml',
#  'mar08-0004-01.jpg',
#  'mar08-0004-02.jpg',
#  'mar08-0004-05.jpg',
#  'mar08-0004-04.jpg',
#  'mar08-0004-03.jpg']
#
# dir for drug 2:
# 20181214_cea3f6aa-cd1c-4152-98bb-bbb7b977497a
# ['image-02.jpg',
#  'image-05.jpg',
#  'image-04.jpg',
#  'image-03.jpg',
#  '9e027111-4dce-47fb-bafb-90191891a2f8.xml',
#  'image-06.jpg',
#  'image-01.jpg']

# %% [markdown]
# Looks like each directory has an xml file with a randomized name, not related to the dir name.  It also has some number of images, and those images may or may not include the name of the drug. Lets print an xml file and check it out.

# %%
test_filename = test_data_dir+drug_dirs[0]+'/7b291076-36db-9793-e053-2991aa0a9f53.xml'
x = etree.parse(test_filename)
print(etree.tostring(x, pretty_print=True)[:1000])
# Out:
# b'<?xml-stylesheet href="http://www.accessdata.fda.gov/spl/stylesheet/spl.xsl" type="text/xsl"?>\n<document xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="urn:hl7-org:v3" xsi:schemaLocation="urn:hl7-org:v3 http://www.accessdata.fda.gov/spl/schema/spl.xsd">\n   <id root="7b291076-36db-9793-e053-2991aa0a9f53"/>\n   <code code="34391-3" codeSystem="2.16.840.1.113883.6.1" displayName="HUMAN PRESCRIPTION DRUG LABEL"/>\n   <title>Dexamethasone Sodium Phosphate Injection,USP</title>\n   <effectiveTime value="20181101"/>\n   <setId root="94472ddb-ae1d-4a11-a673-81254d562e6b"/>\n   <versionNumber value="5"/>\n   <author>\n      <time/>\n      <assignedEntity>\n         <representedOrganization>\n            <id root="1.3.6.1.4.1.519.1" extension="059888437"/>\n            <name>Asclemed USA, Inc.</name>\n            <assignedEntity>\n               <assignedOrganization/>\n            </assignedEntity>\n         </representedOrganization>\n      </assignedEntity>\n   </author>\n   <component>\n      <st'

# %% [markdown]
# That's too much to deal with.  Let's read it into pandas.

# %%
df_list = pd.read_html(test_filename, flavor='bs4') # This will convert an xml file into a list of DataFrames
print(len(df_list))
# Out:
# 7

# %%
for i,df in enumerate(df_list):
    print(f'Dataframe: {i}')
    display(df)
# Out:
# Dataframe: 0
#              0                                                  1
# 0       Author                                             Dosage
# 1  Cavanagh  1  3 mg/kg of body weight per 24 hours by constan...
# 2          NaN                                                NaN
# 3  Dietzman  2  2 to 6 mg/kg of body weight as a single intrav...
# 4          NaN                                                NaN
# 5     Frank  3  40 mg initially followed by repeat intravenous...
# 6          NaN                                                NaN
# 7      Oaks  4  40 mg initially followed by repeat intravenous...
# 8          NaN                                                NaN
# 9   Schumer  5  1 mg/kg of body weight as a single intravenous...
# Dataframe: 1
#              0             1         2          3
# 0  Product No.      NDC  No.  Strength  Vial Size
# 1       500601  63323-506-01  10 mg/mL       1 mL
# Dataframe: 2
#              0             1         2          3
# 0  Product No.      NDC  No.  Strength  Vial Size
# 1       501610  63323-516-10  10 mg/mL      10 mL
# Dataframe: 3
#                                                    0
# 0  THE 0.75% CONCENTRATION OF BUPIVACAINE HYDROCH...
# Dataframe: 4
#                                                     0            1  \
# 0                                      Type of  Block        Conc.
# 1                                                (mL)         (mg)
# 2                                 Local  infiltration      0.25% 4
# 3                                            Epidural    0.75% 2,4
# 4                                              0.5% 4        10-20
# 5                                             0.25% 4        10-20
# 6                                              Caudal       0.5% 4
# 7                                             0.25% 4        15-30
# 8                                   Peripheral nerves       0.5% 4
# 9                                             0.25% 4    5 to max.
# 10                                      Retrobulbar 3      0.75% 4
# 11                                        Sympathetic        0.25%
# 12                                           Dental 3  0.5%  w/epi
# 13                              Epidural 3  Test Dose  0.5%  w/epi
# 14  1With continuous (intermittent) techniques, re...          NaN
#
#                    2                                     3  \
# 0          Each Dose                         Motor Block 1
# 1                NaN                                   NaN
# 2        up to  max.                            up to max.
# 3              10-20                                75-150
# 4             50-100                  moderate to complete
# 5              25-50                  partial  to moderate
# 6              15-30                                75-150
# 7            37.5-75                              moderate
# 8         5 to  max.                            25 to max.
# 9      12.5 to  max.                 moderate  to complete
# 10               2-4                                 15-30
# 11             20-50                                50-125
# 12  1.8-3.6 per site                         9-18 per site
# 13               2-3  10-15 (10-15 micrograms epinephrine)
# 14               NaN                                   NaN
#
#                         4
# 0                     NaN
# 1                     NaN
# 2                       —
# 3                complete
# 4                     NaN
# 5                     NaN
# 6    moderate to complete
# 7                     NaN
# 8   moderate  to complete
# 9                     NaN
# 10               complete
# 11                      —
# 12                      —
# 13                      —
# 14                    NaN
# Dataframe: 5
#                0                                                  1      2  \
# 0        NDC No.                                          Container   Fill
# 1            NaN  0.25%—Contains 2.5 mg bupivacaine hydrochlorid...    NaN
# 2   0409-1559-10                                  Single-dose vials  10 mL
# 3   0409-1559-30                                  Single-dose vials  30 mL
# 4   0409-1587-50                                Multiple-dose vials  50 mL
# 5            NaN  0.5%—Contains 5 mg bupivacaine hydrochloride p...    NaN
# 6   0409-1560-10                                  Single-dose vials  10 mL
# 7   0409-1560-29                                  Single-dose vials  30 mL
# 8   0409-1610-50                                Multiple-dose vials  50 mL
# 9            NaN  0.75%—Contains 7.5 mg bupivacaine hydrochlorid...    NaN
# 10  0409-1582-10                                  Single-dose vials  10 mL
# 11  0409-1582-29                                  Single-dose vials  30 mL
#
#             3
# 0    Quantity
# 1         NaN
# 2   box of 10
# 3   box of 10
# 4    box of 1
# 5         NaN
# 6   box of 10
# 7   box of 10
# 8    box of 1
# 9         NaN
# 10  box of 10
# 11  box of 10
# Dataframe: 6
#                                                    0                    1  \
# 0                                            NDC No.            Container
# 1  0.25% with epinephrine 1:200,000—Contains 2.5 ...                  NaN
# 2                                       0409-1746-10    Single-dose vials
# 3                                       0409-1746-30    Single-dose vials
# 4                                       0409-1752-50  Multiple-dose vials
# 5  0.5% with epinephrine 1:200,000—Contains 5 mg ...                  NaN
# 6                                       0409-1749-03   Single-dose ampuls
# 7                                       0409-1749-10    Single-dose vials
# 8                                       0409-1749-29    Single-dose vials
# 9                                       0409-1755-50  Multiple-dose vials
#
#        2          3
# 0   Fill   Quantity
# 1    NaN        NaN
# 2  10 mL  box of 10
# 3  30 mL  box of 10
# 4  50 mL   box of 1
# 5    NaN        NaN
# 6   3 mL  box of 10
# 7  10 mL  box of 10
# 8  30 mL  box of 10
# 9  50 mL   box of 1

# %% [raw]
# This also looks awful.  Pandas has not scraped the majority of content.  Instead, it only seems to have grabbed items that are formatted in a tabular manner, which misses very important information (the drug name, for instance...).  This is a very messy xml file that will be difficult to parse, and will probably require a parsing engine made by hand.  Before we do that... maybe someone has tried to do this already?  A bit of googling leads to a different resource:

# %% [markdown]
# # OpenFDA database

# %% [markdown]
# Looks like the [openFDA](https://open.fda.gov/tools/downloads/) has currated json files from the FDA label xml files.  This probably doesn't have everything we need, but it is almost certainly a cleaner way to start.

# %%
data = json.load(open('../test_data/drug-label-0001-of-0007.json'))
print(data.keys())
data['meta']
# Out:
# dict_keys(['meta', 'results'])
# {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#  'last_updated': '2018-12-14',
#  'license': 'https://open.fda.gov/license/',
#  'results': {'limit': 20000, 'skip': 0, 'total': 131198},
#  'terms': 'https://open.fda.gov/terms/'}

# %% [markdown]
# Well we have two keys, 'meta' and 'results'.  If we take a quick peak, we know that we don't really care about meta.  I bet 'results' is more promising...

# %%
df = pd.DataFrame(data['results'])
df.head()
# Out:
#   abuse accessories                                  active_ingredient  \
# 0   NaN         NaN  [HPUS Active Ingredients Each dose contains eq...
# 1   NaN         NaN          [Active ingredient Colloidal oatmeal 43%]
# 2   NaN         NaN                                                NaN
# 3   NaN         NaN  [Active ingredient (in each extended-release t...
# 4   NaN         NaN                                                NaN
#
#   active_ingredient_table                                  adverse_reactions  \
# 0                     NaN                                                NaN
# 1                     NaN                                                NaN
# 2                     NaN  [6 ADVERSE REACTIONS Use of levocetirizine dih...
# 3                     NaN                                                NaN
# 4                     NaN  [6 ADVERSE REACTIONS The most common adverse r...
#
#                              adverse_reactions_table  \
# 0                                                NaN
# 1                                                NaN
# 2  [<table ID="_RefID0EWPAC" width="75%"> <captio...
# 3                                                NaN
# 4  [<table ID="_RefID0EOOAG" width="100%"> <capti...
#
#                animal_pharmacology_and_or_toxicology  \
# 0                                                NaN
# 1                                                NaN
# 2  [13.2 Animal Toxicology Reproductive Toxicolog...
# 3                                                NaN
# 4                                                NaN
#
#                                           ask_doctor ask_doctor_or_pharmacist  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3  [Ask a doctor before use if you have •persiste...                      NaN
# 4                                                NaN                      NaN
#
#   ask_doctor_or_pharmacist_table       ...         \
# 0                            NaN       ...
# 1                            NaN       ...
# 2                            NaN       ...
# 3                            NaN       ...
# 4                            NaN       ...
#
#   use_in_specific_populations_table user_safety_warnings version  \
# 0                               NaN                  NaN       1
# 1                               NaN                  NaN       1
# 2                               NaN                  NaN       1
# 3                               NaN                  NaN       1
# 4                               NaN                  NaN       1
#
#   veterinary_indications                                           warnings  \
# 0                    NaN  [Warnings If symptoms persist or worsen, consu...
# 1                    NaN  [Warnings For external use only. When using th...
# 2                    NaN                                                NaN
# 3                    NaN  [Warnings Do not use •for children under 12 ye...
# 4                    NaN                                                NaN
#
#                                warnings_and_cautions  \
# 0                                                NaN
# 1                                                NaN
# 2  [5 WARNINGS AND PRECAUTIONS 1.Avoid engaging i...
# 3                                                NaN
# 4  [5 WARNINGS AND PRECAUTIONS •Angioedema: incre...
#
#   warnings_and_cautions_table warnings_table  \
# 0                         NaN            NaN
# 1                         NaN            NaN
# 2                         NaN            NaN
# 3                         NaN            NaN
# 4                         NaN            NaN
#
#                                           when_using when_using_table
# 0                                                NaN              NaN
# 1  [When using this product Do not get into eyes....              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
#
# [5 rows x 133 columns]

# %% [markdown]
# We have tabular data now, at least.  More investigation to continue...
