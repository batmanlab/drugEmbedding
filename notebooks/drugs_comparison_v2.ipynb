# %% [markdown]
# # Preprocessing SMILES data

# %%
import os
import pandas as pd

# %%
file = "all_drugs_smi"
f = open(file)

# %%
#extract SMILES string and drug names
smi = []
for line in f:
    drg = []
    smile_string = line.split()[0]
    drug_name = line.split()[-1]
    drg.append(smile_string)
    drg.append(drug_name)
    smi.append(drg)
f.close()

# %%
df_smi = pd.DataFrame(smi, columns = ["SMILES_STRING", "DRUG_NAME"])

# %%
print(df_smi.shape)
df_smi.head()
# Out:
# (1385, 2)
#                                        SMILES_STRING      DRUG_NAME
# 0      Nc1nc(NC2CC2)c2ncn([C@H]3C=C[C@@H](CO)C3)c2n1       Abacavir
# 1  CC(=O)O[C@H]1CC[C@@]2(C)C(=CCC3C4CC=C(c5cccnc5...    Abiraterone
# 2                               CC(=O)NCCCS(=O)(=O)O    Acamprosate
# 3           CCCC(=O)Nc1ccc(OCC(O)CNC(C)C)c(C(C)=O)c1     Acebutolol
# 4  CC(=O)CC(c1ccc([N+](=O)[O-])cc1)c1c(O)c2ccccc2...  Acenocoumarol

# %% [markdown]
# # Preprocessing drug labels data

# %%
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
frames = []
directory = "./JSON"
cols_openfda = ["openfda.spl_set_id","openfda.brand_name","openfda.generic_name"
               ,"openfda.package_ndc","openfda.product_type","openfda.route","openfda.rxcui",
               "openfda.substance_name","openfda.unii","description"]
for f in os.listdir(directory):
    if f.endswith(".json"):
        print(f)
        data = json.load(open(directory + "/" + f))
        #pull openFDA drug identifiers
        df = json_normalize(data["results"])
        df_openfda = df[cols_openfda]
        print(df_openfda.shape)
        frames.append(df_openfda)
# Out:
# drug-label-0003-of-0007.json
# (20000, 10)
# drug-label-0004-of-0007.json
# (20000, 10)
# drug-label-0005-of-0007.json
# (20000, 10)
# drug-label-0002-of-0007.json
# (20000, 10)
# drug-label-0007-of-0007.json
# (12340, 10)
# drug-label-0006-of-0007.json
# (20000, 10)
# drug-label-0001-of-0007.json
# (20000, 10)

# %%
#merge multiple JSON files
df_openfda_master = pd.concat(frames)

# %%
#one long string
df_openfda_master.iloc[6]
# Out:
# openfda.spl_set_id                   [4d11cc46-3942-1561-e054-00144ff8d46c]
# openfda.brand_name        [SERIOUS SKINCARE SERIOUS C3 PLASMA BIO TECHNO...
# openfda.generic_name      [AVOBENZONE, OCTOCRYLENE, OCTINOXATE, OCTISALA...
# openfda.package_ndc                                          [53755-101-04]
# openfda.product_type                                       [HUMAN OTC DRUG]
# openfda.route                                                     [TOPICAL]
# openfda.rxcui                                                           NaN
# openfda.substance_name    [OCTINOXATE, OCTISALATE, OXYBENZONE, OCTOCRYLE...
# openfda.unii              [G63QQF2NOX, 95OOS7VE0Y, 4X49Y0596W, 5A68WGF6W...
# description                                                             NaN
# Name: 6, dtype: object

# %%
#multiple strings
df_openfda_master.iloc[6].loc["openfda.generic_name"]
# Out:
# ['AVOBENZONE, OCTOCRYLENE, OCTINOXATE, OCTISALATE, OXYBENZONE']

# %%
df_openfda_master.iloc[6].loc["openfda.substance_name"]
# Out:
# ['OCTINOXATE', 'OCTISALATE', 'OXYBENZONE', 'OCTOCRYLENE', 'AVOBENZONE']

# %%
#extract single value from list
df_openfda_master = df_openfda_master.applymap(lambda x:x[0] if type(x) is list and len(x)==1 else x)

# %%
#sample data
df_openfda_master.iloc[6]
# Out:
# openfda.spl_set_id                     4d11cc46-3942-1561-e054-00144ff8d46c
# openfda.brand_name        SERIOUS SKINCARE SERIOUS C3 PLASMA BIO TECHNOL...
# openfda.generic_name      AVOBENZONE, OCTOCRYLENE, OCTINOXATE, OCTISALAT...
# openfda.package_ndc                                            53755-101-04
# openfda.product_type                                         HUMAN OTC DRUG
# openfda.route                                                       TOPICAL
# openfda.rxcui                                                           NaN
# openfda.substance_name    [OCTINOXATE, OCTISALATE, OXYBENZONE, OCTOCRYLE...
# openfda.unii              [G63QQF2NOX, 95OOS7VE0Y, 4X49Y0596W, 5A68WGF6W...
# description                                                             NaN
# Name: 6, dtype: object

# %%
df_openfda_master.shape
# Out:
# (132340, 10)

# %%
len(df_openfda_master["openfda.spl_set_id"].unique())
# Out:
# 95134

# %%
t2 = df_openfda_master.loc[df_openfda_master["openfda.spl_set_id"].isna()]
t2.head()
# Out:
#    openfda.spl_set_id openfda.brand_name openfda.generic_name  \
# 30                NaN                NaN                  NaN
# 31                NaN                NaN                  NaN
# 32                NaN                NaN                  NaN
# 33                NaN                NaN                  NaN
# 34                NaN                NaN                  NaN
#
#    openfda.package_ndc openfda.product_type openfda.route openfda.rxcui  \
# 30                 NaN                  NaN           NaN           NaN
# 31                 NaN                  NaN           NaN           NaN
# 32                 NaN                  NaN           NaN           NaN
# 33                 NaN                  NaN           NaN           NaN
# 34                 NaN                  NaN           NaN           NaN
#
#    openfda.substance_name openfda.unii description
# 30                    NaN          NaN         NaN
# 31                    NaN          NaN         NaN
# 32                    NaN          NaN         NaN
# 33                    NaN          NaN         NaN
# 34                    NaN          NaN         NaN

# %% [markdown]
# ### Remove missing values

# %%
df_openfda_master = df_openfda_master.loc[df_openfda_master["openfda.spl_set_id"].notna()]
df_openfda_master.shape
# Out:
# (95133, 10)

# %% [markdown]
# ### Data quality (missing values)

# %% [markdown]
# substance name, unii are more complete than RxCUI
#
# NLM associates U.S. Food and Drug Administration (FDA) generated unique ingredient identifiers (UNIIs) to RxNorm (SAB=RXNORM) atoms of term type IN. The association is made by an exact string match to the RxNorm ingredient string (case insensitive) from the official FDA substance list. These UNII codes are found in RXNSAT.RRF as values of the attribute ATN='UNII_CODE'. The UNII is a non-proprietary, free, unique, unambiguous, non semantic, alphanumeric identifier based on a substance’s molecular structure and/or descriptive information. For more information on the FDA UNII codes, please refer to this FDA web page.

# %%
df_openfda_master.count()
# Out:
# openfda.spl_set_id        95133
# openfda.brand_name        95133
# openfda.generic_name      95133
# openfda.package_ndc       95132
# openfda.product_type      95133
# openfda.route             93524
# openfda.rxcui             64613
# openfda.substance_name    93207
# openfda.unii              92925
# description               34588
# dtype: int64

# %% [markdown]
# ### Select human presciption drug

# %%
df_openfda_master.groupby("openfda.product_type")["openfda.spl_set_id"].count()
# Out:
# openfda.product_type
# HUMAN OTC DRUG             60038
# HUMAN PRESCRIPTION DRUG    35095
# Name: openfda.spl_set_id, dtype: int64

# %%
df_openfda_rx = df_openfda_master.loc[df_openfda_master["openfda.product_type"] == "HUMAN PRESCRIPTION DRUG"]
df_openfda_rx.groupby("openfda.product_type")["openfda.spl_set_id"].count()
# Out:
# openfda.product_type
# HUMAN PRESCRIPTION DRUG    35095
# Name: openfda.spl_set_id, dtype: int64

# %% [markdown]
# ### Use generic name or substance name?
# case study: Morphine

# %%
df_openfda_rx.loc[df_openfda_rx["openfda.generic_name"]=="MORPHINE"]
# Out:
#                          openfda.spl_set_id         openfda.brand_name  \
# 6289   3ad95865-a77c-41da-b572-e5c0bb404c79  Opium Tincture Deodorized
# 8060   e2a5697a-cc41-4cf1-b3a8-59b0268740d7  Opium Tincture Deodorized
# 1129   1d9a7065-45c2-0e3f-e054-00144ff8d46c                  MORPHINUM
# 1173   1d858c8b-9797-209b-e054-00144ff8d46c                  MORPHINUM
# 1904   1dac198e-49bb-725b-e054-00144ff8d46c                  MORPHINUM
# 8636   1d87ae72-46e2-343b-e054-00144ff88e88                  MORPHINUM
# 10252  1c6d882b-4f2c-2cfb-e054-00144ff88e88                  MORPHINUM
#
#       openfda.generic_name           openfda.package_ndc  \
# 6289              MORPHINE  [0187-4203-16, 0187-4203-04]
# 8060              MORPHINE  [42799-217-02, 42799-217-01]
# 1129              MORPHINE                  10191-1004-2
# 1173              MORPHINE                  10191-1002-2
# 1904              MORPHINE                  10191-1005-2
# 8636              MORPHINE                  10191-1003-2
# 10252             MORPHINE                  10191-1001-2
#
#           openfda.product_type openfda.route openfda.rxcui  \
# 6289   HUMAN PRESCRIPTION DRUG          ORAL        830196
# 8060   HUMAN PRESCRIPTION DRUG          ORAL        830196
# 1129   HUMAN PRESCRIPTION DRUG    SUBLINGUAL           NaN
# 1173   HUMAN PRESCRIPTION DRUG    SUBLINGUAL           NaN
# 1904   HUMAN PRESCRIPTION DRUG    SUBLINGUAL           NaN
# 8636   HUMAN PRESCRIPTION DRUG    SUBLINGUAL           NaN
# 10252  HUMAN PRESCRIPTION DRUG    SUBLINGUAL           NaN
#
#             openfda.substance_name openfda.unii  \
# 6289                      MORPHINE   76I7G6D29C
# 8060                      MORPHINE   76I7G6D29C
# 1129   ABT-925 ANHYDROUS FREE BASE   E6CKI5C54O
# 1173   ABT-925 ANHYDROUS FREE BASE   E6CKI5C54O
# 1904   ABT-925 ANHYDROUS FREE BASE   E6CKI5C54O
# 8636   ABT-925 ANHYDROUS FREE BASE   E6CKI5C54O
# 10252  ABT-925 ANHYDROUS FREE BASE   E6CKI5C54O
#
#                                              description
# 6289   DESCRIPTION Opium Tincture, USP (Deodorized), ...
# 8060   DESCRIPTION Opium Tincture, USP (Deodorized), ...
# 1129                                                 NaN
# 1173                                                 NaN
# 1904                                                 NaN
# 8636                                                 NaN
# 10252                                                NaN

# %%
df_openfda_rx[df_openfda_rx["openfda.rxcui"]=="830196"]
# Out:
#                         openfda.spl_set_id         openfda.brand_name  \
# 6289  3ad95865-a77c-41da-b572-e5c0bb404c79  Opium Tincture Deodorized
# 5086  674a969a-707d-41a9-b7c3-b90cbf2909e3  Opium Tincture Deodorized
# 8060  e2a5697a-cc41-4cf1-b3a8-59b0268740d7  Opium Tincture Deodorized
#
#      openfda.generic_name           openfda.package_ndc  \
# 6289             MORPHINE  [0187-4203-16, 0187-4203-04]
# 5086    MORPHINE TINCTURE                  62559-153-04
# 8060             MORPHINE  [42799-217-02, 42799-217-01]
#
#          openfda.product_type openfda.route openfda.rxcui  \
# 6289  HUMAN PRESCRIPTION DRUG          ORAL        830196
# 5086  HUMAN PRESCRIPTION DRUG          ORAL        830196
# 8060  HUMAN PRESCRIPTION DRUG          ORAL        830196
#
#      openfda.substance_name openfda.unii  \
# 6289               MORPHINE   76I7G6D29C
# 5086               MORPHINE   76I7G6D29C
# 8060               MORPHINE   76I7G6D29C
#
#                                             description
# 6289  DESCRIPTION Opium Tincture, USP (Deodorized), ...
# 5086  DESCRIPTION Opium Tincture, USP (Deodorized), ...
# 8060  DESCRIPTION Opium Tincture, USP (Deodorized), ...

# %% [markdown]
# Using RxNorm API, can't find Morphine in the drug label data. RxCUI = 830196 is associated with "opium" using RxNorm Nav

# %%
ind = df_openfda_master["openfda.rxcui"] == "7052"
df_openfda_master[ind]
# Out:
# Empty DataFrame
# Columns: [openfda.spl_set_id, openfda.brand_name, openfda.generic_name, openfda.package_ndc, openfda.product_type, openfda.route, openfda.rxcui, openfda.substance_name, openfda.unii, description]
# Index: []

# %% [markdown]
# Substance name seems to be more accurate to match "drug_name" in all_drugs.smi file. However, this expects to be a fuzzy match. Can we find mappings between UNII and SMILES? If so we can link SMILES at UNII level for each prescription drug

# %% [markdown]
# ### SMILES strings are different pulled from different data sources: (same chemical formula C17H19NO3, same UNII 76I7G6D29C)
#
# 1. From the all_drugs.smi file <br/>
# CN1CC[C@]23c4c5ccc(O)c4O[C@H]2[C@@H](O)C=C[C@H]3[C@H]1C5
# 2. Pubchem <br/>
# CN1CC[C@]23[C@@H]4[C@H]1CC5=C2C(=C(C=C5)O)O[C@H]3[C@H](C=C4)O <br/>
# https://pubchem.ncbi.nlm.nih.gov/compound/morphine#section=Top
# 3. Drugbank <br/>
# [H][C@@]12OC3=C(O)C=CC4=C3[C@@]11CCN(C)[C@]([H])(C4)[C@]1([H])C=C[C@@H]2O <br/>
# https://www.drugbank.ca/drugs/DB00295
# 4. ZINC <br/>
# C[NH+]1CC[C@]23c4c5ccc(c4O[C@H]2[C@H](C=C[C@H]3[C@H]1C5)O)O <br/>
# http://zinc.docking.org/substance/3812983

# %% [markdown]
# ### Convert SMILES strings to canonical form
# the canonical SMILES are the same for all_drugs.smi, Pubchem and Drugbank

# %%
from rdkit import Chem
 
smis = ["CN1CC[C@]23c4c5ccc(O)c4O[C@H]2[C@@H](O)C=C[C@H]3[C@H]1C5",
        "CN1CC[C@]23[C@@H]4[C@H]1CC5=C2C(=C(C=C5)O)O[C@H]3[C@H](C=C4)O",
        "[H][C@@]12OC3=C(O)C=CC4=C3[C@@]11CCN(C)[C@]([H])(C4)[C@]1([H])C=C[C@@H]2O",
        "C[NH+]1CC[C@@]23c4c5ccc(c4O[C@H]2[C@@H](C=C[C@H]3[C@@H]1C5)O)O"
       ]

cans = [Chem.MolToSmiles(Chem.MolFromSmiles(smi),canonical = True) for smi in smis]
cans
# Out:
# ['CN1CC[C@]23c4c5ccc(O)c4O[C@H]2[C@@H](O)C=C[C@H]3[C@H]1C5',
#  'CN1CC[C@]23c4c5ccc(O)c4O[C@H]2[C@@H](O)C=C[C@H]3[C@H]1C5',
#  'CN1CC[C@]23c4c5ccc(O)c4O[C@H]2[C@@H](O)C=C[C@H]3[C@H]1C5',
#  'C[NH+]1CC[C@@]23c4c5ccc(O)c4O[C@H]2[C@H](O)C=C[C@H]3[C@@H]1C5']

# %% [markdown]
# ### Try exact drug name matching

# %%
#get all drug names from .smi file
smi_drugs = [x.lower() for x in df_smi.DRUG_NAME]

# %%
len(smi_drugs)
# Out:
# 1385

# %%
spl_drugs = []

for s in df_openfda_rx["openfda.substance_name"]:
    if isinstance(s,list):
        spl_drugs = spl_drugs + s
    elif isinstance(s,str):
        spl_drugs.append(s)

# %%
#get unique substance names
spl_drugs = list(set(spl_drugs))

# %%
spl_drugs = [x.lower() for x in spl_drugs]

# %%
len(spl_drugs)
# Out:
# 2829

# %%
spl_unii = []

for s in df_openfda_rx["openfda.unii"]:
    if isinstance(s,list):
        spl_unii = spl_unii + s
    elif isinstance(s,str):
        spl_unii.append(s)

# %%
#get unique substance names
spl_unii = list(set(spl_unii))

# %%
#intersection of drug names
drugs_intersection = list(set(smi_drugs) & set(spl_drugs))

# %%
print(len(drugs_intersection))
#print a few samples
print(drugs_intersection[:10])
# Out:
# 510
# ['liothyronine', 'cisplatin', 'clobazam', 'stavudine', 'chlorzoxazone', 'amcinonide', 'cefotetan', 'spironolactone', 'glycine', 'loratadine']

# %%
#SPL drugs that are not in smiles file using exact string matching
drugs_not_in_smi = list(set(spl_drugs) - set(smi_drugs))
print(len(drugs_not_in_smi))
#print a few sampels
print(drugs_not_in_smi[:10])
# Out:
# 2319
# ['sus scrofa stomach', 'azathioprine sodium', 'salmonella enterica subsp. enterica serovar typhi', 'methylparaben', 'selexipag', 'lidocaine hydrochloride', 'borage', 'yeast mannan', 'borrelia burgdorferi', 'moxetumomab pasudotox']

# %% [markdown]
# ### Create drug - UNII dictionary

# %%
#pull unique drug-unii pairs from SPL 
drug_unii_dict = {}
for index, row in df_openfda_rx.iterrows():
    #if both fields are lists and have the same length
    if isinstance(row["openfda.substance_name"],list) and isinstance(row["openfda.unii"],list):
        if len(row["openfda.substance_name"]) == len(row["openfda.unii"]):
            for i in range(len(row["openfda.substance_name"])):
                key = row["openfda.substance_name"][i]
                val = row["openfda.unii"][i]
                drug_unii_dict[key] = val
    #if both fileds are single strings
    elif isinstance(row["openfda.substance_name"],str) and isinstance(row["openfda.unii"],str):
        key = row["openfda.substance_name"]
        val = row["openfda.unii"]
        drug_unii_dict[key] = val

# %%
len(drug_unii_dict)
# Out:
# 2688

# %%
len(spl_drugs)
# Out:
# 2829

# %%
len(spl_unii)
# Out:
# 3167

# %% [markdown]
# ### Step 1: Use UNII-List lookup file

# %%
#download UNII data from https://fdasis.nlm.nih.gov/srs/jsp/srs/uniiListDownload.jsp
unii_file = "./UNII_Data/UNII Records 25Oct2018.txt"
unii_data = pd.read_table(unii_file, sep="\t",low_memory=False)

# %%
unii_data.head()
# Out:
#          UNII                                                 PT  \
# 0  00174624E2  2-(5-CYANO-2-(6-(METHOXYCARBONYL)-7-METHYL-3-O...
# 1  0129526470  5,8-DIMETHOXY(1,2,4)TRIAZOLO(1,5-C)PYRIMIDIN-2...
# 2  0258808825                           MACROPIPER EXCELSUM LEAF
# 3  0377415922                       N-DESMETHYLVENLAFAXINE, (S)-
# 4  0457970679                                         VERRUCARIN
#
#              RN NCIT   EC  RXCUI   PUBCHEM  ITIS      NCBI PLANTS  GRIN MPNS  \
# 0  1613620-10-2  NaN  NaN    NaN       NaN   NaN       NaN    NaN   NaN  NaN
# 1   219715-62-5  NaN  NaN    NaN  11446888   NaN       NaN    NaN   NaN  NaN
# 2           NaN  NaN  NaN    NaN       NaN   NaN  130373.0    NaN   NaN  NaN
# 3   392332-59-1  NaN  NaN    NaN   9860056   NaN       NaN    NaN   NaN  NaN
# 4    54018-05-2  NaN  NaN    NaN       NaN   NaN       NaN    NaN   NaN  NaN
#
#    INN_ID            MF                     INCHIKEY  \
# 0     NaN  C27H28F3N6O3  IHTRPSMRGYWUIM-HSZRJFAPSA-O
# 1     NaN      C7H9N5O2  DBJPBHJHAPAUQU-UHFFFAOYSA-N
# 2     NaN           NaN                          NaN
# 3     NaN     C16H25NO2  MKAFOJAJJMUXLW-OAHLLOKOSA-N
# 4     NaN           NaN                          NaN
#
#                                               SMILES       INGREDIENT_TYPE  \
# 0  COC(=O)C1=C(C)N(C2=NNC(=O)N2[C@@H]1C3=CC=C(C=C...          IONIC MOIETY
# 1                         COC1=CN=C(OC)N2N=C(N)N=C12  INGREDIENT SUBSTANCE
# 2                                                NaN  INGREDIENT SUBSTANCE
# 3               CNC[C@H](C1=CC=C(OC)C=C1)C2(O)CCCCC2  INGREDIENT SUBSTANCE
# 4                                                NaN  INGREDIENT SUBSTANCE
#
#    Unnamed: 17
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
import math
unii_smiles_dict = {}
for index, row in unii_data.iterrows():
    key = row.UNII
    val = row.SMILES
    if type(val) is str:
        unii_smiles_dict[key] = val

# %%
len(unii_smiles_dict)
# Out:
# 69953

# %%
#matched 68% drugs to smiles
df_lst = []
for key in drug_unii_dict.keys():
    drug = key
    unii = drug_unii_dict[key]
    try:
        smi = unii_smiles_dict[unii]
        try:
            smile = Chem.MolToSmiles(Chem.MolFromSmiles(smi),canonical = True)
        except:
            smile = smi
    except KeyError:
        smile = float("NaN")
    df_lst.append([drug,unii,smile])
df_output = pd.DataFrame(df_lst, columns = ["drug", "unii", "smiles_unii"])

# %%
df_output.shape
# Out:
# (2688, 3)

# %% [markdown]
# ### Step 2: Use PubChemPy API

# %%
import pubchempy as pcp

# %%
lst = []
for index, row in df_output.iterrows():
    try:
        com = pcp.get_compounds(row["drug"],"name")
        if len(com) > 0:
            smi = com[0].isomeric_smiles
            lst.append(smi)
        else:
            lst.append(float("NaN"))
    except:
        lst.append("HTTPError")

# %%
df_output["smiles_api"] = lst

# %% [markdown]
# ### Step3: Add smi file as validation set

# %%
#create drug name: SMILES string dictionary
dict_smi = {}
for index,row in df_smi.iterrows():
    key = row["DRUG_NAME"].upper()
    val = row["SMILES_STRING"]
    dict_smi[key] = val

# %%
lst = []
for index, row in df_output.iterrows():
    try:
        smile = dict_smi[row["drug"]]
        lst.append(smile)
    except:
        lst.append(float("NaN"))

# %%
df_output["smiles_file"] = lst

# %%
df_output.head()
# Out:
#                                  drug        unii  \
# 0                          NABUMETONE  LW0TIW155Z
# 1             BUSPIRONE HYDROCHLORIDE  207LT9J9OC
# 2                              OXYGEN  S88TT14065
# 3  PAROXETINE HYDROCHLORIDE ANHYDROUS  3I3T11UD2S
# 4           VENLAFAXINE HYDROCHLORIDE  7D7RX5A8MO
#
#                                         smiles_unii  \
# 0                        COc1ccc2cc(CCC(C)=O)ccc2c1
# 1   Cl.O=C1CC2(CCCC2)CC(=O)N1CCCCN1CCN(c2ncccn2)CC1
# 2                                               O=O
# 3  Cl.Fc1ccc([C@@H]2CCNC[C@H]2COc2ccc3c(c2)OCO3)cc1
# 4               COc1ccc(C(CN(C)C)C2(O)CCCCC2)cc1.Cl
#
#                                           smiles_api  \
# 0                  CC(=O)CCC1=CC2=C(C=C1)C=C(C=C2)OC
# 1  C1CCC2(C1)CC(=O)N(C(=O)C2)CCCCN3CCN(CC3)C4=NC=...
# 2                                                O=O
# 3                                                NaN
# 4             CN(C)CC(C1=CC=C(C=C1)OC)C2(CCCCC2)O.Cl
#
#                   smiles_file
# 0  COc1ccc2cc(CCC(C)=O)ccc2c1
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN

# %% [markdown]
# ### Step 4: Combine SMILES from 3 data sources

# %%
lst = []
for index, row in df_output.iterrows():
    if type(row["smiles_unii"]) is str:
        try:
            can = Chem.MolToSmiles(Chem.MolFromSmiles(row["smiles_unii"]),canonical = True)
        except:
            can = row["smiles_unii"]
    elif type(row["smiles_api"]) is str:
        try:
            can = Chem.MolToSmiles(Chem.MolFromSmiles(row["smiles_api"]),canonical = True)
        except:
            can = row["smiles_api"]
    elif type(row["smiles_file"]) is str:
        try:
            can = Chem.MolToSmiles(Chem.MolFromSmiles(row["smiles_file"]),canonical = True)
        except:
            can = row["smiles_file"]
    else:
        can = float("NaN")
    lst.append(can)

# %%
df_output["smiles_can"] = lst

# %%
df_output.count()
# Out:
# drug           2688
# unii           2688
# smiles_unii    1849
# smiles_api     1816
# smiles_file     508
# smiles_can     2022
# dtype: int64

# %%
#check drugs with missing smiles_can
ind = df_output["smiles_can"].isna()
df_output[ind]
# Out:
#                                                    drug        unii  \
# 192        CHITOSAN LOW MOLECULAR WEIGHT (20-200 MPA.S)  SBD1A2I75N
# 203                                      HEPARIN SODIUM  ZZ45AB24CA
# 234                                       CONESTAT ALFA  5QS67N4551
# 238                           COLESEVELAM HYDROCHLORIDE  P4SG24WI5Q
# 261                                   ACONITUM NAPELLUS  WQZ3G9PF0H
# 265                                 MATRICARIA RECUTITA  5EF0HWI5WU
# 266                                        COMFREY ROOT  M9VVZ08EKQ
# 267                                   BRYONIA ALBA ROOT  V5VD430YW9
# 268                           PHYTOLACCA AMERICANA ROOT  I76KB35JEV
# 269                                        BLACK COHOSH  6L5ZL09795
# 270                        TOXICODENDRON PUBESCENS LEAF  6IO182RP7A
# 274                           STRYCHNOS NUX-VOMICA SEED  269XH13919
# 2686                               SITOTROGA CEREALELLA  9T28I7BPNO
#
#      smiles_unii smiles_api smiles_file smiles_can
# 192          NaN        NaN         NaN        NaN
# 203          NaN        NaN         NaN        NaN
# 234          NaN        NaN         NaN        NaN
# 238          NaN        NaN         NaN        NaN
# 261          NaN        NaN         NaN        NaN
# 265          NaN        NaN         NaN        NaN
# 266          NaN        NaN         NaN        NaN
# 267          NaN        NaN         NaN        NaN
# 268          NaN        NaN         NaN        NaN
# 269          NaN        NaN         NaN        NaN
# 270          NaN        NaN         NaN        NaN
# 274          NaN        NaN         NaN        NaN
# 275          NaN        NaN         NaN        NaN
# 276          NaN        NaN         NaN        NaN
# 278          NaN        NaN         NaN        NaN
# 288          NaN        NaN         NaN        NaN
# 289          NaN        NaN         NaN        NaN
# 291          NaN        NaN         NaN        NaN
# 292          NaN        NaN         NaN        NaN
# 293          NaN        NaN         NaN        NaN
# 295          NaN        NaN         NaN        NaN
# 297          NaN        NaN         NaN        NaN
# 299          NaN        NaN         NaN        NaN
# 301          NaN        NaN         NaN        NaN
# 302          NaN        NaN         NaN        NaN
# 310          NaN        NaN         NaN        NaN
# 312          NaN        NaN         NaN        NaN
# 317          NaN        NaN         NaN        NaN
# 318          NaN        NaN         NaN        NaN
# 347          NaN        NaN         NaN        NaN
# ...          ...        ...         ...        ...
# 2583         NaN        NaN         NaN        NaN
# 2584         NaN        NaN         NaN        NaN
# 2588         NaN        NaN         NaN        NaN
# 2592         NaN        NaN         NaN        NaN
# 2593         NaN        NaN         NaN        NaN
# 2596         NaN        NaN         NaN        NaN
# 2599         NaN        NaN         NaN        NaN
# 2600         NaN        NaN         NaN        NaN
# 2607         NaN        NaN         NaN        NaN
# 2612         NaN        NaN         NaN        NaN
# 2613         NaN        NaN         NaN        NaN
# 2614         NaN        NaN         NaN        NaN
# 2616         NaN        NaN         NaN        NaN
# 2619         NaN        NaN         NaN        NaN
# 2622         NaN        NaN         NaN        NaN
# 2626         NaN        NaN         NaN        NaN
# 2631         NaN        NaN         NaN        NaN
# 2633         NaN        NaN         NaN        NaN
# 2645         NaN        NaN         NaN        NaN
# 2646         NaN        NaN         NaN        NaN
# 2647         NaN        NaN         NaN        NaN
# 2655         NaN        NaN         NaN        NaN
# 2659         NaN        NaN         NaN        NaN
# 2663         NaN        NaN         NaN        NaN
# 2671         NaN        NaN         NaN        NaN
# 2674         NaN        NaN         NaN        NaN
# 2675         NaN        NaN         NaN        NaN
# 2680         NaN        NaN         NaN        NaN
# 2685         NaN        NaN         NaN        NaN
# 2686         NaN        NaN         NaN        NaN
#
# [666 rows x 6 columns]

# %% [markdown]
# Lots of them are not chemical compounds, e.g. cat's claw? Bluefish?

# %% [markdown]
# ## Save as HDF

# %%
df_output.to_hdf("drugs_smi.h4",key = "rx")
# Out:
# /Users/keyu/anaconda3/envs/py37/lib/python3.6/site-packages/pandas/core/generic.py:1996: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->['drug', 'unii', 'smiles_unii', 'smiles_api', 'smiles_file', 'smiles_can']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %% [markdown]
# # Past Code

# %% [markdown]
# ### PubChemPy API

# %%
import pubchempy as pcp

# %%
#retreving substances
results = pcp.get_compounds("ABT-925 ANHYDROUS FREE BASE","name")

# %%
results
# Out:
# [Compound(9916104)]

# %%
for com in results:
    print(com.isomeric_smiles)
# Out:
# CC(C)(C)C1=NC(=CC(=N1)N2CCN(CC2)CCCSC3=NC=CC(=O)N3)C(F)(F)F

# %%
#create drug name: SMILES string dictionary
dict_smi = {}
for index,row in df_smi.iterrows():
    key = row["DRUG_NAME"].lower()
    val = row["SMILES_STRING"]
    dict_smi[key] = val

# %%
df_lst = []
for d in drugs_intersection:
    #SMILES from file
    smi_f = dict_smi[d]
    smi_f_norm = Chem.MolToSmiles(Chem.MolFromSmiles(smi_f),canonical = True)
    #SMILES from PubChem API
    com = pcp.get_compounds(d,"name")
    if len(com) > 0:
        smi_api = com[0].isomeric_smiles
        smi_api_norm = Chem.MolToSmiles(Chem.MolFromSmiles(smi_api),canonical = True)
    else:
        smi_api = ""
        smi_api_norm = ""
    row_lst = [d, smi_f, smi_f_norm, smi_api, smi_api_norm, smi_f_norm == smi_api_norm]
    df_lst.append(row_lst)

# %%
df_api_val = pd.DataFrame(df_lst, columns = ["drug_name", "smi_f", "smi_f_norm", "smi_api", "smi_api_norm", "same_smi_flag"])

# %%
df_api_val.groupby("same_smi_flag").size()
# Out:
# same_smi_flag
# False     80
# True     430
# dtype: int64

# %% [markdown]
# 84% exact match

# %%
df_api_val.loc[df_api_val["same_smi_flag"] == False]
# Out:
#           drug_name                                              smi_f  \
# 7        crotamiton                            CC=CC(=O)N(CC)c1ccccc1C
# 14       famotidine               NC(N)=Nc1nc(CSCCC(N)=NS(N)(=O)=O)cs1
# 23         selenium                                             S=[Se]
# 34    sulfasalazine  O=C(O)c1cc(/N=N/c2ccc(S(=O)(=O)Nc3ccccn3)cc2)c...
# 36      doxycycline  C[C@H]1c2cccc(O)c2C(=O)C2=C(O)[C@]3(O)C(=O)C(C...
# 40      alprostadil  CCCCC[C@H](O)C=C[C@H]1[C@H](O)CC(=O)[C@@H]1CCC...
# 46      polidocanol                                   CCCCCCCCCCCCOCCO
# 47        estradiol  CCCCC(=O)O[C@H]1CC[C@H]2[C@@H]3CCc4cc(O)ccc4[C...
# 57           silver                   Nc1ccc(S(=O)(=O)[N-]c2ncccn2)cc1
# 64       olanzapine                Cc1cc2c(s1)Nc1ccccc1N=C2N1CCN(C)CC1
# 73        clozapine              CN1CCN(C2=Nc3cc(Cl)ccc3Nc3ccccc32)CC1
# 85        tolvaptan  Cc1ccccc1C(=O)Nc1ccc(C(=O)N2CCC[C@@H](O)c3cc(C...
# 105         lithium                                              [Li+]
# 107       auranofin  CCP(CC)(CC)=[Au]S[C@@H]1O[C@H](COC(C)=O)[C@@H]...
# 115     granisetron             CN1C2CCCC1CC(NC(=O)c1nn(C)c3ccccc13)C2
# 117        succimer                               O=C(O)C(S)C(S)C(=O)O
# 130     clindamycin  CCC[C@@H]1C[C@@H](C(=O)NC(C(C)Cl)[C@H]2O[C@H](...
# 131      leucovorin  Nc1nc(=O)c2c([nH]1)NCC(CNc1ccc(C(=O)N[C@H](CCC...
# 141         lindane  Cl[C@H]1[C@H](Cl)[C@@H](Cl)[C@@H](Cl)[C@H](Cl)...
# 148      aprepitant  C[C@@H](O[C@H]1OCCN(Cc2n[nH]c(=O)[nH]2)[C@H]1c...
# 152   levetiracetam                           CC[C@H](C(N)=O)N1CCCC1=O
# 154      guanfacine                        N=C(N)NC(=O)Cc1c(Cl)cccc1Cl
Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)O[P@...
#
#                                             smi_f_norm  \
# 7                              CC=CC(=O)N(CC)c1ccccc1C
# 14                NC(N)=Nc1nc(CSCCC(N)=NS(N)(=O)=O)cs1
# 23                                              S=[Se]
# 34   O=C(O)c1cc(/N=N/c2ccc(S(=O)(=O)Nc3ccccn3)cc2)c...
# 36   C[C@H]1c2cccc(O)c2C(=O)C2=C(O)[C@]3(O)C(=O)C(C...
# 40   CCCCC[C@H](O)C=C[C@H]1[C@H](O)CC(=O)[C@@H]1CCC...
# 46                                    CCCCCCCCCCCCOCCO
# 47   CCCCC(=O)O[C@H]1CC[C@H]2[C@@H]3CCc4cc(O)ccc4[C...
# 57                    Nc1ccc(S(=O)(=O)[N-]c2ncccn2)cc1
# 64                 Cc1cc2c(s1)Nc1ccccc1N=C2N1CCN(C)CC1
# 73               CN1CCN(C2=Nc3cc(Cl)ccc3Nc3ccccc32)CC1
# 85   Cc1ccccc1C(=O)Nc1ccc(C(=O)N2CCC[C@@H](O)c3cc(C...
# 105                                              [Li+]
# 107  CCP(CC)(CC)=[Au]S[C@@H]1O[C@H](COC(C)=O)[C@@H]...
# 115             CN1C2CCCC1CC(NC(=O)c1nn(C)c3ccccc13)C2
# 117                               O=C(O)C(S)C(S)C(=O)O
# 130  CCC[C@@H]1C[C@@H](C(=O)NC(C(C)Cl)[C@H]2O[C@H](...
# 131  Nc1nc(=O)c2c([nH]1)NCC(CNc1ccc(C(=O)N[C@H](CCC...
# 141  Cl[C@H]1[C@H](Cl)[C@@H](Cl)[C@@H](Cl)[C@H](Cl)...
# 148  C[C@@H](O[C@H]1OCCN(Cc2n[nH]c(=O)[nH]2)[C@H]1c...
# 152                           CC[C@H](C(N)=O)N1CCCC1=O
# 154                        N=C(N)NC(=O)Cc1c(Cl)cccc1Cl
# 163  CN(C)c1cc(NC(=O)CNC(C)(C)C)c(O)c2c1C[C@H]1C[C@...
# 171  C[C@H]1[C@H](NC(=O)/C(=N\OC(C)(C)C(=O)O)c2csc(...
# 175  CN1[C@H]2C[C@H](OC(=O)[C@H](CO)c3ccccc3)C[C@@H...
# 176                    CC(C)(C)NCC(O)COc1nsnc1N1CCOCC1
# 178                                             [Al+3]
# 184                                 CC(C)(S)C(N)C(=O)O
# 189  CSCC[C@H](NC(=O)[C@H](Cc1c[nH]c2ccccc12)NC(=O)...
# 190                             O=C1O[Pt]OC(=O)C12CCC2
# ..                                                 ...
# 348  CC=CC1=C(C(=O)O)N2C(=O)[C@@H](NC(=O)[C@H](N)c3...
# 359  COc1cc2c(c(OC)c1OC)-c1ccc(OC)c(=O)cc1C(NC(C)=O...
# 362  CC(O)CN1CCN(CC(=O)[O-])CCN(CC(=O)[O-])CCN(CC(=...
# 369  CCC(C)n1ncn(-c2ccc(N3CCN(c4ccc(OC[C@H]5CO[C@](...
# 375                           CN(C)N=Nc1[nH]cnc1C(N)=O
# 380  CCCCC(=O)OCC(=O)[C@]1(O)Cc2c(O)c3c(c(O)c2[C@@H...
# 381                                     N[Pt](N)(Cl)Cl
# 390        C[N+]1(C)CCC(OC(=O)C(O)(c2ccccc2)C2CCCC2)C
# 463           C1=CC(=C(C=C1[C@H]([C@@H](C(=O)O)N)O)O)O
# 471          CCCN(CCC1=CC=CS1)[C@H]2CCC3=C(C2)C=CC=C3O
# 472  C[C@@H]1CCN([C@H](C1)C(=O)O)C(=O)[C@H](CCCN=C(...
# 483     CN1[C@@H]2CC[C@H]1CC(C2)OC(=O)C(CO)C3=CC=CC=C3
# 484                     C1CCN(CC1)C2=NC(=N)N(C(=C2)N)O
# 486  CC1=C(C(CCC1)(C)C)/C=C/C(=C/C=C/C(=C/C(=O)O)/C)/C
# 494  C1C[C@@H]2CN(C(=O)C3=C2C(=CC=C3)C1)[C@@H]4CN5C...
# 498                        CC1=C(N=CN1)CSCCNC(=NC)NC#N
# 508  C1=NC2=C(C(=N1)N)N=CN2[C@H]3[C@@H]([C@@H]([C@H...
#
#                                           smi_api_norm  same_smi_flag
# 7                            C/C=C/C(=O)N(CC)c1ccccc1C          False
# 14              NC(N)=Nc1nc(CSCC/C(N)=N/S(N)(=O)=O)cs1          False
# 23                                                [Se]          False
# 34   O=C(O)C1=C/C(=N/Nc2ccc(S(=O)(=O)Nc3ccccn3)cc2)...          False
# 36   C[C@H]1c2cccc(O)c2C(O)=C2C(=O)[C@]3(O)C(O)=C(C...          False
# 40   CCCCC[C@H](O)/C=C/[C@H]1[C@H](O)CC(=O)[C@@H]1C...          False
# 46            CCCCCCCCCCCCOCCOCCOCCOCCOCCOCCOCCOCCOCCO          False
# 47   C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1CC[C...          False
# 57                                                [Ag]          False
# 64                Cc1cc2c(s1)=Nc1ccccc1NC=2N1CCN(C)CC1          False
# 73              CN1CCN(C2=c3ccccc3=Nc3ccc(Cl)cc3N2)CC1          False
# 85   Cc1ccccc1C(=O)Nc1ccc(C(=O)N2CCCC(O)c3cc(Cl)ccc...          False
# 105                                               [Li]          False
# 107  CC(=O)OCC1OC([S-])C(OC(C)=O)C(OC(C)=O)C1OC(C)=...          False
# 115    CN1[C@H]2CCC[C@@H]1CC(NC(=O)c1nn(C)c3ccccc13)C2          False
# 117                       O=C(O)[C@H](S)[C@H](S)C(=O)O          False
# 130  CCC[C@@H]1C[C@@H](C(=O)N[C@H]([C@H](C)Cl)[C@H]...          False
# 131  Nc1nc(=O)c2c([nH]1)NCC(CNc1ccc(C(=O)N[C@@H](CC...          False
# 141                       ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl          False
# 148  C[C@@H](O[C@H]1OCCN(Cc2nc(=O)[nH][nH]2)[C@H]1c...          False
# 152                          CC[C@@H](C(N)=O)N1CCCC1=O          False
# 154                        NC(N)=NC(=O)Cc1c(Cl)cccc1Cl          False
# 163  CN(C)c1cc(NC(=O)CNC(C)(C)C)c(O)c2c1C[C@H]1C[C@...          False
# 171  C[C@H]1[C@H](NC(=O)/C(=N\OC(C)(C)C(=O)O)c2csc(...          False
# 175  CN1[C@H]2CC(OC(=O)[C@H](CO)c3ccccc3)C[C@@H]1[C...          False
# 176                CC(C)(C)NC[C@H](O)COc1nsnc1N1CCOCC1          False
# 178                                               [Al]          False
# 184                            CC(C)(S)[C@@H](N)C(=O)O          False
# 189  CSCC[C@H](NC(=O)[C@H](Cc1c[nH]c2ccccc12)NC(=O)...          False
# 190                      N.N.O=C(O)C1(C(=O)O)CCC1.[Pt]          False
# ..                                                 ...            ...
# 348  C/C=C/C1=C(C(=O)O)N2C(=O)[C@@H](NC(=O)[C@H](N)...          False
# 359  COc1cc2c(c(OC)c1OC)-c1ccc(OC)c(=O)cc1[C@@H](NC...          False
# 362  CC(O)CN1CCN(CC(=O)[O-])CCN(CC(=O)[O-])CCN(CC(=...          False
# 369  CCC(C)n1ncn(-c2ccc(N3CCN(c4ccc(OCC5COC(Cn6cncn...          False
# 375                          CN(C)N/N=C1/N=CN=C1C(N)=O          False
# 380  CCCCC(=O)OCC(=O)[C@]1(O)Cc2c(O)c3c(c(O)c2[C@@H...          False
# 381                                                             False
# 390  C[N+]1(C)CCC(OC(=O)C(O)(c2ccccc2)C2CCCC2)C1.[Br-]          False
# 393  CCOC(=O)O[C@]1(C(=O)COC(=O)CC)CC[C@H]2[C@@H]3C...          False
# 408  CC#CCC(C)[C@H](O)/C=C/[C@@H]1[C@H]2C/C(=C/CCCC...          False
# 422                         C[N+](C)(C)CCOC(N)=O.[Cl-]          False
# 429  CCC[C@@]1(CCc2ccccc2)CC(O)=C([C@H](CC)c2cccc(N...          False
# 431  C1CNCCN1.C[C@]12CC[C@@H]3c4ccc(OS(=O)(=O)O)cc4...          False
# 433                       CC(=O)N=c1sc(S(N)(=O)=O)nn1C          False
# 440  C[C@]12CC[C@@H]3c4ccc(O)cc4C[C@@H](CCCCCCCCCS(...          False
# 441  CN(C)CCOC(c1ccccc1)c1ccccc1.Cn1c(=O)c2[nH]c(Cl...          False
# 446  CC[C@@H]([C@H](C)O)n1ncn(-c2ccc(N3CCN(c4ccc(OC...          False
# 449  CCCCC(F)(F)[C@@]1(O)CC[C@H]2[C@@H](CC(=O)[C@@H...          False
# 455  C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=CC(=NO)CC[C@@H]...          False
# 456                               CN1CCC[C@H]1c1cccnc1          False
# 459     OC[C@H]1O[C@@H](n2cnc3c2NC=NC[C@H]3O)C[C@@H]1O          False
# 463               N[C@H](C(=O)O)[C@H](O)c1ccc(O)c(O)c1          False
# 471               CCCN(CCc1cccs1)[C@H]1CCc2c(O)cccc2C1          False
# 472  CC1CNc2c(cccc2S(=O)(=O)N[C@@H](CCCN=C(N)N)C(=O...          False
# 483        CN1[C@H]2CC[C@@H]1CC(OC(=O)C(CO)c1ccccc1)C2          False
# 484                           N=c1nc(N2CCCCC2)cc(N)n1O          False
# 486    CC1=C(/C=C/C(C)=C/C=C/C(C)=C/C(=O)O)C(C)(C)CCC1          False
# 494       O=C1c2cccc3c2[C@H](CCC3)CN1[C@@H]1CN2CCC1CC2          False
# 498                         CN=C(NC#N)NCCSCc1nc[nH]c1C          False
# 508    Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO)[C@@H](O)[C@H]1O          False
#
# [80 rows x 6 columns]

# %% [markdown]
# ### Alternative way to get SMILES
# most drugs have UNII info. which can be used to find SMILES

# %%
print(sum(df_openfda_rx["openfda.unii"].isna()))
print(sum(df_openfda_rx["openfda.unii"].isna())/df_openfda_rx.shape[0])
# Out:
# 971
# 0.027667758940019944

# %%
#download UNII data from https://fdasis.nlm.nih.gov/srs/jsp/srs/uniiListDownload.jsp
unii_file = "./UNII_Data/UNII Records 25Oct2018.txt"
unii_data = pd.read_table(unii_file, sep="\t",low_memory=False)

# %%
unii_data.head()
# Out:
#          UNII                                                 PT  \
# 0  00174624E2  2-(5-CYANO-2-(6-(METHOXYCARBONYL)-7-METHYL-3-O...
# 1  0129526470  5,8-DIMETHOXY(1,2,4)TRIAZOLO(1,5-C)PYRIMIDIN-2...
# 2  0258808825                           MACROPIPER EXCELSUM LEAF
# 3  0377415922                       N-DESMETHYLVENLAFAXINE, (S)-
# 4  0457970679                                         VERRUCARIN
#
#              RN NCIT   EC  RXCUI   PUBCHEM  ITIS      NCBI PLANTS  GRIN MPNS  \
# 0  1613620-10-2  NaN  NaN    NaN       NaN   NaN       NaN    NaN   NaN  NaN
# 1   219715-62-5  NaN  NaN    NaN  11446888   NaN       NaN    NaN   NaN  NaN
# 2           NaN  NaN  NaN    NaN       NaN   NaN  130373.0    NaN   NaN  NaN
# 3   392332-59-1  NaN  NaN    NaN   9860056   NaN       NaN    NaN   NaN  NaN
# 4    54018-05-2  NaN  NaN    NaN       NaN   NaN       NaN    NaN   NaN  NaN
#
#    INN_ID            MF                     INCHIKEY  \
# 0     NaN  C27H28F3N6O3  IHTRPSMRGYWUIM-HSZRJFAPSA-O
# 1     NaN      C7H9N5O2  DBJPBHJHAPAUQU-UHFFFAOYSA-N
# 2     NaN           NaN                          NaN
# 3     NaN     C16H25NO2  MKAFOJAJJMUXLW-OAHLLOKOSA-N
# 4     NaN           NaN                          NaN
#
#                                               SMILES       INGREDIENT_TYPE  \
# 0  COC(=O)C1=C(C)N(C2=NNC(=O)N2[C@@H]1C3=CC=C(C=C...          IONIC MOIETY
# 1                         COC1=CN=C(OC)N2N=C(N)N=C12  INGREDIENT SUBSTANCE
# 2                                                NaN  INGREDIENT SUBSTANCE
# 3               CNC[C@H](C1=CC=C(OC)C=C1)C2(O)CCCCC2  INGREDIENT SUBSTANCE
# 4                                                NaN  INGREDIENT SUBSTANCE
#
#    Unnamed: 17
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
unii_data.loc[unii_data["UNII"] == "E6CKI5C54O"]
# Out:
#              UNII                           PT           RN NCIT   EC  \
# 58514  E6CKI5C54O  ABT-925 ANHYDROUS FREE BASE  220519-06-2  NaN  NaN
#
#            RXCUI  PUBCHEM  ITIS  NCBI PLANTS  GRIN MPNS  INN_ID            MF  \
# 58514  1661016.0  9916104   NaN   NaN    NaN   NaN  NaN     NaN  C20H27F3N6OS
#
#                           INCHIKEY  \
# 58514  KXVAICSRMHXLJN-UHFFFAOYSA-N
#
#                                                   SMILES  \
# 58514  CC(C)(C)C1=NC(=CC(=N1)C(F)(F)F)N2CCN(CCCSC3=NC...
#
#             INGREDIENT_TYPE  Unnamed: 17
# 58514  INGREDIENT SUBSTANCE          NaN
